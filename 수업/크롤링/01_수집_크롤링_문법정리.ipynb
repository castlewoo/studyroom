# %% [markdown]
# ### 파이썬을 이용한  웹 데이터 수집(크롤링)
#
# 1. 문서 내용 요청 후 읽어오기 urllib 패키지
#     -  urlopen() 접속
#     - read() 데이터 읽어오기
#     - text 속성을 사용해서 데이터 읽어올 수도 있음
#
#
#
# 2. 문서에서 원하는 내용 추출하기(파싱)
#
#
# #### BeautifulSoup 패키지 사용 - find()/findAll()

# %% [markdown]
# #### urllib 패키지 - url을 넘겨주면 데이터를 텍스트 형태로 반환(기본 내장 패키지)
#
#
# - urllib2, urllib3 다른 버전 사용
# - requests 패키지를 사용할 수도 있음

# %%
import requests
# 파이썬 기본 패키지 : HTTP 요청을 보내는 모듈

# %%
url = 'http://www.tistory.com'

# request 패키지의 get(url) 함수 사용 : urllib의 open()과 read() 를 한번에 진행
response = requests.get(url)
# URL 변수에 저장되어 있는 웹주소로 요청신호를 보냄
# 서버(tistory)는 해당 페이지의 소스코드를 클라이언트(현재 프로그램)로 전송하면서 응답하게 됨
# response 변수에는 http://www.tistory.com의 소스코드(html)가 저장되어 있음

# %%
# 정상 응답인지 확인
response.status_code
# 응답에대한 상태코드
# 200은 정상응답
# 400번대 코드 : 클라이언트의 요청이 잘못되었다의 의미(url주소가 틀렸거나 권한이 없는 페이지를 요청했거나...)
# 500번태 코드 : 클라이언트는 문법에 맞게 요청을 했는데 서버측에서 인증이 안되었거나, 서버가 망가졌거나의 상태
# Out:
# 200

# %%
# 요청에 의해 전달된 코드 확인
# 응답객체.text 속성을 통해 확인
response.text
# 브라우저가 사이트에 요청해서 받은 결과 코드랑 동일한 코드가 문자열 형태로 반환됨
# Out:
# '\n\t<!doctype html>\n\t<html lang="ko">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta name="google-site-verification" content="Djy29naX64H0z8fGEOEOd-k40Sp65VRnz1sm_thWPhw" />\n<meta property="og:url" content="https://www.tistory.com">\n<meta property="og:site_name" content="Tistory">\n<meta property="og:title" content="Tistory">\n<meta property="og:description" content="좀 아는 블로거들의 유용한 이야기">\n<meta property="og:image" content="//t1.daumcdn.net/tistory_admin/static/images/openGraph/tistoryOpengraph.png">\n<meta name="description" content="좀 아는 블로거들의 유용한 이야기">\n\t\t<title>TISTORY</title>\n<link rel="icon" href="https://t1.daumcdn.net/tistory_admin/favicon/tistory_favicon_32x32.ico" sizes="any">\n<link rel="icon" type="image/svg+xml" href="https://t1.daumcdn.net/tistory_admin/top_v2/bi-tistory-favicon.svg" />\n<link rel="apple-touch-icon" href="https://t1.daumcdn.net/tistory_admin/top_v2/tistory-apple-touch-favicon.png">\t\t<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/tistory_admin/assets/tistory-web-top/1699333624/static/css/ext/swiper.min.css">\n\t\t<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/tistory_admin/www/style/top/font.css">\n\t\t<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/tistory_admin/assets/tistory-gnb/3.3.1/gnb.min.css">\n\t\t<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/tistory_admin/assets/tistory-web-top/1699333624/static/css/pc/top.css">\n\t\t<script type="text/javascript" src="https://t1.kakaocdn.net/kakao_js_sdk/v1/kakao.min.js" ></script>\n<!--[if lt IE 9]>\n<script src="https://t1.daumcdn.net/tistory_admin/lib/jquery-1.12.4.min.js"></script>\n<![endif]-->\n<!--[if gte IE 9]><!-->\n<script src="https://t1.daumcdn.net/tistory_admin/lib/jquery-3.1.0.min.js"></script>\n<!--<![endif]-->\n<script src="https://t1.daumcdn.net/tistory_admin/lib/fingerprint2-1.4.2.min.js"></script>\n<script type="text/javascript" src="//m1.daumcdn.net/svc/original/U03/cssjs/jquery/plugin/jquery.cookie-1.4.0.min.js"></script>\n<script type="text/javascript" src="//s1.daumcdn.net/svc/original/U03/cssjs/userAgent/userAgent-1.0.14.min.js"></script>\n\t</head>\n\t<body>\n\t\t<div id="kakaoIndex"><!-- 웹접근성용 바로가기 링크 모음 -->\n\t\t\t<a href="#kakaoBody">본문 바로가기</a>\n\t\t\t<a href="#kakaoLnb">메뉴 바로가기</a> <!-- 2017-05-31 수정 : href 값 kakaoGnb -> kakaoLnb 로 변경 -->\n\t\t</div>\n\t\t\n\t\t<div id="kakaoWrap" class="tistory_type1">\n\t\t\t<div id="kakaoHead" role="banner" class="#GNB kakao_head"><!-- head_type1 : 추가타입 -->\n<div class="inner_header">\n\t<h1>\n\t\t<a href="/" id="kakaoServiceLogo" class="#logo img_common_tistory tit_tistory">티스토리</a>\n\t</h1>\n\t<div id="kakaoGnb" role="navigation" class="gnb_tistory">\n\t\t<h2 class="screen_out">서비스 주요 메뉴</h2>\n\t\t<ul class="list_gnb">\n\t\t\t<li ><a href="/feed" class="link_gnb">피드</a></li>\n\t\t\t<li ><a href="/category" class="link_gnb">스토리</a></li>\n\t\t\t<li ><a href="/skin" class="link_gnb">스킨</a></li>\n\t\t\t<li ><a href="/community" class="link_gnb">포럼</a></li>\n\t\t</ul>\n\t</div>\n\t<div class="info_tistory">\n\t\t<div class="logn_tistory" style="display:none">\n\t\t\t<h2 class="screen_out">로그인정보</h2>\n\t\t\t<a href="/auth/login?redirectUrl=http%3A%2F%2Fwww.tistory.com%2F" class="link_log_info">로그인하기</a>\n\t\t\t<a href="/member/join" class="btn_tistory btn_log_info">가입하기</a>\n\t\t</div>\n\t</div>\n</div>\n\t\t\t</div>\n\t\t\t<hr class="hide">\n\t\t\t<div id="kakaoContent" role="main">\n\t\t\t\t<div id="cMain">\n\t\t\t\t\t\n<div id="mFeature" class="feture_main feture_top">\n\t<h2 class="screen_out">PRPMOTION</h2>\n\t<div class="swiper-container">\n\t\t<div class="swiper-wrapper main_slide">\n\t\t\t\t<div class="swiper-slide scene_slide  init_slide" style="background-image:url(https://img1.daumcdn.net/thumb/R1920x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fsection%2Foc%2Fa076c43fd54d49af81bfe68606ec6106)">\n\t\t\t\t\t<div class="dimm_g_type2"></div>\n\t\t\t\t\t<div class="scene_content">\n\t\t\t\t\t\t<div class= ...

# %%
r = requests.get("https://google.co.kr")
r
r.text
len(r.text)
r.text[0:100]
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="r5up2WCX0I8eYdEw4WMd4Q">(function(){var _g={kEI:\'EXJyZYepCsatoASPuqHQBw\',kEXPI:\'0,1361119,4348,207,4804,2316,383,1129371,1921,1195812,668,380090,16114,19397,9287,22431,1361,284,12027,17588,4998,17075,6885,32448,1983,2891,11754,606,50058,13246,13491,230,20583,4,59617,27044,6630,7596,1,42154,2,39761,5679,1021,31122,4568,6255,23421,1252,33064,2,2,1,26632,8155,23351,8702,11804,6,1923,52238,20199,20136,14,82,52946,3030,11151,4665,1804,35269,2413,9400,476,1159,44008,5215548,13,6217,712,2,225,71,283,133,49,531,37,5993636,2803219,3306,141,795,30294,2,63,36,6,4,1,26,6,1,8,1,7,1,6,2,3,4,29,23940067,4044107,1008,15664,43887,3,1603,3,499,3,2121276,23031936,4126,8673,8409,2878,335,11486,729,1236,5472,11979,7459,3117,1655,4223,4240,10366,10078,6308,815,4586,3419,3,509,1179,1283,769,27,6,5,15,265,48,1329,3457,697,4,872,436,3,667,1760,6,2468,5120,1320,914,1102,49,264,780,983,6131,1652,482,290,897,1302,171,1252,108,853,149,2070,313,146,518,602,2,23,4,1532,1,6,631,3,1954,617,443,230,1120,1796,156,1545,769,733,326,352,57,218,3,2060,88,60,147,6,1,6,257,2481,202,1427,588,2279,5,1169,2,270,723,88,1921,235,549,37,1,6,1261,2,3,18,101,2374,25,1972,195,122,3,4,2,2,2,271,4,5,724,783,315,3,406,187,265,650,1104,255,380,4,58,431,56,675,4,2437,505,323,382,13,625,342,1220,146,458,408,533,477,121,1107,4,687,11,80,773,138,1522,339,392,97,1,1,115,412,89,94,276,951,47,328,105,903,7,1,8,416,1491,1982,21385916,359102,1541,218,1620,3,2662\',kBL:\'Tfrd\',kOPI:89978449};(function(){var a;(null==(a=window.google)?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'webhp\';google.kHL=\'ko\';})();(function(){\nvar h=this||self;function l(){return void 0!==window.google&&void 0!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}\nfunction t(a,b,c,d,k){var e="";-1===b.search("&ei=")&&(e="&ei="+p(d),-1===b.search("&lei=")&&(d=q(d))&&(e+="&lei="+d));d="";var g=-1===b.search("&cshid=")&&"slh"!==a,f=[];f.push(["zx",Date.now().toString()]);h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();null!=c&&f.push(["opi",c.toString()]);for(c=0;c<f.length;c++){if(0===c||0<c)d+="&";d+=f[c][0]+"="+f[c][1]}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google.log=function(a,b,c,d,k,e){e=void 0===e?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){delete n[g]};a.src=c}};google.logUrl=function(a,b){b=void 0===b?l:b;return t("",a,b)};}).call(this);(function(){google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};var d=[];google.fce=function(a,b,c,e){d.push([a,b,c,e])};google.qce=d;}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for ...

# %%
# 네이버 메인 페이지 확인
url = "http://www.naver.com"
r = requests.get(url)
r.status_code
r.text
len(r.text)
# Out:
# 233216

# %% [markdown]
# #### 파라미터 전달 방법
# - 파라미터란? : 사이트의 문서를 요청할 때 서버로 전달되는 정보
# - 함수의 파라미터 처럼 문서를 찾기위한 정보나 명령을 수행하기 위한 정보를 같이 전달하게 되는데 그 정보를 파라미터라고 함
# - 서버에 파라미터 전송방법
#     - 파라미터 전송 방법은 url에 ? 뒤에 파라미터=값&파라미터2=값 으로 전송
#         - 사이트에 따라서 잘못된 접속으로 인지하고 에러처리할 수 있음
#     - 파라미터를 dict로 구성해서 get(params=dict)
#
#
# - https://sports.news.naver.com/news?oid=477&aid=0000312064
# - params = {'param1': 'value1', 'param2': 'value2'}
# - res = requests.get(URL, params=params)

# %%
base_url = "https://sports.news.naver.com/news" # 기본 url
'https://sports.news.naver.com/news?oid=065&aid=0000255145'
param_url ="https://sports.news.naver.com/news?oid=477&aid=0000312064"  
# 파라미터가 포함된 url

# %%
# 파라미터 전달 방식 1 : get방식 - url에 파라미터 포함
# site에 따라 접근 거부할 수도 있음
res1 = requests.get(param_url)
res1.status_code
# Out:
# 200

# %%
# 파라미터 전달 방식 2 : get 방식 : params= dict사용
# oid=477&aid=0000312064
param = {'oid':477, 'aid':'0000312064'}
res2=requests.get(base_url,params=param)
res2.status_code
# Out:
# 200

# %% [markdown]
# #### urllib 패키지 사용한 소스 추출

# %%
from urllib.request import urlopen # 사이트에 요청 신호를 보내는 함수

# %%
url = "https://www.nate.com"
html = urlopen(url)
html
#<http.client.HTTPResponse at 0x2a60cc87c70> : 상태코드와 소스코드가 있습니다.

# %%
# 응답객체에서 소스코드 읽어오기 
# - 응답객체.read() - 한번 읽어오면 그 후에는 읽어도 빈 문자열이 나옴
html.read()
# Out:
# b''

# %%
type(rawtext)
bytes(rawtext)
print(rawtext.decode('utf8'))
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="msapplication-starturl" content="//www.nate.com/" />
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="nate:title" content="" />
# <meta name="nate:description" content="네이트 이슈UP" />
# <meta name="nate:site_name" content="네이트 홈" />
# <meta name="nate:url" content="https://www.nate.com/" />
# <meta name="nate:image" content="" />
# <meta name="description" content="새로워진 nate에서 당신의 오늘을 만나보세요"/>
# <meta property="og:title" content="한눈에 보는 오늘 : 네이트" />
# <meta property="og:url" content="https://www.nate.com/" />
# <meta property="og:image" content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" />
# <meta property="og:description" content="새로워진 nate에서 당신의 오늘을 만나보세요" />
#
#
#
# <title>한눈에 보는 오늘 : 네이트</title>
# <link rel="stylesheet" href="/css/common.min.css?v=202309201110_01" type="text/css">
# <link href="//main.nateimg.co.kr/img/v7/favicon_32.ico"  type="image/x-icon" rel="shortcut icon" />
# <link rel="canonical" href="//www.nate.com" />
# <script type="text/javascript" src="/js/common/jquery-1.9.1.min.js"></script>
# <script type="text/javascript" >
# 	var isSvc = true; var isInfoAjax = true;
# 	var make = 't';
# 	var isMakeLogin = '';
# 	var host = 'www.nate.com';
# 	var isNateLogin = (isMakeLogin == "Y") ? true : false;
# 	var myId = "";
# 	var iSvcSeq  ='3';
# 	var iSvcSeqB ='6';
# 	var iSvcSeqC ='2';
# 	var currentWeatherIndex = [0,11,8];
# 	var iSvcSeqW = iSvcSeqB;
# 	var isCommsbarOpen = ('N' == 'Y') ? true : false;
# 	var loginType = '';
# 	var isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);
# 	var isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000
# 	var isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);
# 	var isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);
# 	if (isTablet)
# 	{
# 	    document.write('<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />');
# 	}
# 	var loginBoxName 	= "아이디 or @이하 모두 입력";
# 	var hostInfo 	 	= (host.length > 0) ? '//' + host : '';
#
# 	var verIssue01 		= '202312081002';
# 	var verIssue02 		= '202312081002';
# 	var verIssue03 		= '202312081002';
# 	var verIssue04 		= '202312081002';
# 	var verIssue05 		= '202312081002';
# 	var verIssue06 		= '202312081002';
# 	var verIssue07 		= '202312081002';
#
# 	var verNateTV		= '202312081033';
# 	var verIssueKeyword	= '202312081040';
# 	var verToonNBook	= '202312081027';
#
# 	var verNateQ01		= '202312081028';
# 	var verRanking06	= '202312081004';
#
# 	var verGnbRoll		= '202312081002';
# 	var verNewsBox 		= '202312081042';
# 	var verShopRecomm	= '202312081011';
# 	var verNateQ02		= '202312081005';
#
# 	var verPannTotal		= '202312081042';
# 	var verPannWomanLife	= '202312081036';
# 	var verPannTeens		= '202312081036';
# 	var verPannEnter		= '202312081036';
# 	var verTodayKeyword 	= '202312081042';
# 	var verWorkLife			= '202312081036';
# 	var verKeywordAd		= '202312081018';
# 	var verAdFunFun			= '202312081036';
# 	var verBizSearch 		= '202311171636';
# 	var verPann01 			= '201907240835';
# 	var verPann02 			= '201907240835';
#
# 	var shoppingInspection 		= 'N';
# 	var isEmergencyShoppingTab 	= 'N';
# 	var isAutoRefresh 			= true;
# 	var isChangeTab 			= false;
# 	var nateAwardsStat			= '';
# 	var isViewKeywordRank		= 'N';
# 	var isEmergencyToonNBookTab = 'N';
#
# 	//]]>
# 	</script>
# 	<script type="text/javascript" src="/js/common/nate_general_v20170627.js?v=202311061245_15"></script>
# 	<script type="text/javascript" src="/js/common/ac_v5.js?v=20221017_07"></script>
#
#
#
#
# 		<script type="text/javascript" src="/js/common/nate_logout_v20170627.js?v=202001141024_01"></script>
# 		<script type="text/javascript">
# 		 //<![CDATA[
# 			var bLogout = false;
# 	    	if (isLogout()) { fillLogout(); }
# 		 //]]>
# 		</script>
#
#
# </head>
# <body>
# 	<script type="text/javascript">
# 	 //<![CDATA[
# 		pageEnd2('st');
# 	 //]]>
# 	</script>
# 	<div id="mainContainer">
# 		<div class="area_access">
# 			<h2>네이트 메인페이지 주요 내용 바로가기</h2>
# 			<ul>
# 				<li><a href="#search"><strong>통합검색 바로가기</strong></a></li>
#
#
# 					<li><a href="#UI"><strong>로그인영역 바로가기</strong></a></li>
#
# 				<li><a href="#news_area"><strong>본문영역 바로가기</strong></a></li>
# 			</ul>
# 		</div>
# 			<div id="container">
# 			<div id="header">
#
#
#
#
#
# <div id="NateBi" class="area_bi" role="banner">
#     <h1 title="네이트" class="bi"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
#
#
#
#
#
#
# <div id="divignb" class="area_ignb">
# <h2>독립GNB</h2>
# <h3>편리한 네이트</h3>
# 	<ul>
# 		<li><a href="https://search.daum.net/nate?thr=sbma&w=tot&q=%EB%84%A4%EC%9D%B4%ED%8A%B8%EC%95%B1" onmousedown="nc('NBI04');">네이트앱</a></li>
# 		<li><a href="//nateonweb.nate.com/" onmousedown="nc('NBI05');">네이트온</a></li>
# 		<li><a href="http://www.cymera.com/main/ko" onmousedown="nc('NBI07');">싸이메라</a></li>
# 	</ul>
# </div>
#
#
#
#
#
#
# <div class="area_search" role="search">
#     <h2>통합검색</h2>
#     <form id="search" name="search" action="https://search.daum.net/nate" accept-charset="utf-8" onsubmit="return checkSearchForm()">
# 		<input type="hidden" id="thr" name="thr" value="sbma" />
# 		<input type="hidden" id="w" name="w" value="tot" />
#         <fieldset>
#             <legend>통합검색 입력</legend>
#             <div id="acWrap" class="home" onmouseover="ac_LoadByNateMain();">
#                 <input class="type_text" id="q" name="q" value="" autocomplete="off" type="text" style="ime-mode:active" onkeydown="return checkSearchQEnter(event)" onmousedown="clickSearchKeywordAd()" />
#                 <input id="acBtn" title="검색" class="type_btn" type="submit">
#                 <div id="acDiv" style="display:none;"></div>
#             </div>
#         </fieldset>
#     </form>
#     <input type="hidden" id="premiumText" name="premiumText" title="" value="" />
#     <input type="hidden" id="premiumLink" name="premiumLink" title="" value="" />
#     <input type="hidden" id="statCode" name="statCode" title="" value="" />
# 	<div class="search_keyword">
# 		<dl>
# 			<dd>
# 				<a id="onclick_semantic01" href="https://search.daum.net/nate?w=tot&amp;q=%ED%99%8D%EC%A7%84%EA%B2%BD+%EB%94%B8+%ED%95%98%EB%B2%84%EB%93%9C+%ED%95%B4%EB%AA%85&amp;rtmaxcoll=DNS" onmousedown="setNcCode('NSC11|NSC21|NSC31',iSvcSeq-1);">홍진경 해명</a>
#                 <a id="onclick_semantic02" href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EB%B0%B1%EB%82%B4%EC%9E%A5" onmousedown="setNcCode('NSC12|NSC22|NSC32',iSvcSeq-1);">백내장 검사</a>
#                 <a id="onclick_semantic03" href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%B9%98%EC%95%84%EB%B3%B4%ED%97%98" onmousedown="setNcCode('NSC13|NSC23|NSC33',iSvcSeq-1);">치아보험 비교</a>
#                 <a id="onclick_semantic04" href="https://search.daum.net/nate?w=tot&amp;q=%EC%8B%A0%EC%83%81%ED%9B%88+11%EC%9D%BC+%EC%9E%85%EB%8C%80&amp;rtmaxcoll=DNS" onmousedown="setNcCode('NSC14|NSC24|NSC34',iSvcSeq-1);">신상훈 11일 입대</a>
#                 <a id="onclick_semantic05" href="https://search.daum.net/nate?w=tot&amp;q=%EC%8B%A0%EB%8F%99%EC%97%BD+%EA%B9%80%EC%9C%A0%EC%A0%95+MC&amp;rtmaxcoll=DNS" onmousedown="setNcCode('NSC15|NSC25|NSC35',iSvcSeq-1);">신동엽 김유정 MC</a>
# 			</dd>
# 		</dl>
# 	</div>
#     <a href="https://m.nate.com/aichat.html" target="_blank" class="link-ngpt" onmousedown="nc('NNC01');">AI챗 바로가기</a>
# </div>
#
#
#
#
#
#
# <div id="divGnb" class="area_gnb" role="navigation">
# 	<h2>GNB</h2>
# 	<ul>
# 		<li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>
# 		<li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>
# 		<li class="pann"><a href="https://pann.nate.com/" onmousedown="nc('NGB02');">판</a></li>
# 		<li class="chat1"><a href="https://m.nate.com/aichat.html" target="_blank" onmousedown="nc('NGB51');">AI챗</a><em class="beta">beta</em></li>
# 		<li class="tv"><a href="https://tv.nate.com/" onmousedown="nc('NGB43');">TV</a></li>
# 		<li class="comics"><a href="https://toonnbook.nate.com/" onmousedown="nc('NGB44');">툰앤북</a></li>
# 		<li class="fortune"><a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">운세</a></li>
# 		<li class="game"><a href="http://game.nate.com/" onmousedown="nc('NGB06');">게임</a></li>
# 		<li class="shopping"><a href="//shopping.nate.com/" onmousedown="nc('NGB17');">쇼핑</a></li>
# 		<li class="teamroom"><a href="https://nateonweb.nate.com/teamroom/" title="함께하는 일이 쉬워진다" onmousedown="nc('NGB42');">팀룸</a></li>
# 		<li class=""><a href="https://view.nate.com/" title="네이트뷰" onmousedown="nc('NGB50');">네이트뷰</a></li>
# 		<li class="more">
# 			<a id="aGnbMore" href="javascript:;" title="전체 서비스 더보기" onmousedown="nc('NGB31');">더보기</a>
# 			<div class="list_svc" style="display:none">
# 				<ul class="row_first">
# 					<li><a href="//news.nate.com" onmousedown="nc('NSD30');"><strong>뉴스</strong></a></li>
# 					<li><a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">날씨</a></li>
# 					<li><a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">스포츠</a></li>
# 					<li><a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">연예</a></li>
# 					<li><a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">아이돌24</a></li>
# 					<li><a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">랭킹뉴스</a></li>
# 				</ul>
# 				<ul class="row_second">
# 					<li><a href="https://pann.nate.com/" onmousedown="nc('NSD68');"><strong>판</strong></a></li>
# 					<li><a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">톡톡</a></li>
# 					<li><a href="https://pann.nate.com/talk/imageTheme/index" onmousedown="nc('NSD08');">판포토</a></li>
# 					<li><a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">팬톡</a></li>
# 				</ul>
# 				<ul class="row_third">
# 					<li><a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">네이트온</a></li>
# 					<li><a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">네이트캐쉬</a></li>
# 					<li><a href="https://sms.nate.com/" onmousedown="nc('NSD35');">문자메시지</a></li>
# 					<li><a href="https://mail.nate.com/pims/" onmousedown="nc('NSD34');">주소록</a></li>
# 				</ul>
# 				<ul class="row_fourth">
# 					<li><a href="//mobile.nate.com/" onmousedown="nc('NSD41');">컬러링</a></li>
# 					<li><a href="//editor.nate.com/" onmousedown="nc('NSD42');">이슈UP추천</a></li>
# 				</ul>
# 				<span><a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">서비스 전체보기</a></span>
#
# 				<button type="button" value="더보기 닫기" title="더보기 닫기" onmousedown="nc('NSD95');">더보기 닫기</button>
# 			</div>
# 		</li>
# 	</ul>
# </div>
# <div class="area_rtkwd type_alone" id="keywordRank">
# 	<h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">실시간 검색어</a></h3>
#
# </div>
# <div class="area_biz type_alone" id="bizRank">
# 	<h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">비즈 검색어</a></h3>
#
# </div>
#
#
#
#
#
#
#
#
#
# 		<div class="todayBox" id='divTodayKeywordArea' onmouseover="todayKeyword.stopTodayKeyword()" onmouseout="todayKeyword.startTodayKeyword()">
# 			<div id='divTodayKeyword'>
# 				<a href="https://news.nate.com/?keyword_dtm=2023-12-08 10:05:01&keyword_sq=75309" class="keyword" title="10월 경상수지 2년래 최대" onmousedown="nc('TOD56');">10월 경상수지 2년래 최대</a>
# 			</div>
# 			<div class="kwrd_slide">
# 				<div class="today_tit">
# 					<a href="https://news.nate.com/" onmousedown="nc('TOD61');">
# 						<div class="logoimg">
# 							<div class="circle step1"></div>
# 							<div class="circle step2"></div>
# 						</div>
# 						<span class="svcname">오늘</span>
# 					</a>
# 				</div>
# 				<button type="button" title="이전" id="Prev" class="btn prev" onmousedown="nc('TOD91');" onclick="todayKeyword.viewPreNext('P')"><span>오늘 키워드 이전 내용</span></button>
# 				<button type="button" title="다음" id="Next" class="btn next" onmousedown="nc('TOD92');" onclick="todayKeyword.viewPreNext('N')"><span>오늘 키워드 다음 내용</span></button>
# 			</div>
# 		</div>
#
#
#
# 			</div>
# 			<hr />
# 			<div id="content">
#
#
#
#
#
#
#
# 				<div id="UI" class="area_auth">
# 					<h2>회원 로그인 영역</h2>
#
#                     <script type="text/javascript">
#                     //<![CDATA[
#                         document.write('<script type="text/javascript" src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2022111801"><\/script>');
#                     //]]>
#                     </script>
#
#                         <form id="f_login" name="f_login" action="https://xo.nate.com/LoginAuth.sk" method="post" target="_top" onsubmit="return SubmitCheck();">
#                         	<input type="hidden" id="redirect" name="redirect" value="https://www.nate.com/" />
#                             <input type="hidden" id="PASSWD_RSA" name="PASSWD_RSA" value="" />
#                             <input type="hidden" id="domain" name="domain" value="nate.com" />
#                             <input type="hidden" name="cpurl" value="www_ndr.nate.com%2Flogin%2F" />
#                             <fieldset>
# 								<legend>회원 로그인</legend>
# 								<label for="ID" class="label_id nHide">아이디 or @이하 모두 입력</label>
# 								<input type="text" id="ID" name="ID" class="input_id" title="아이디 or @이하 모두 입력" style="ime-mode:disabled;" value="" />
# 								<label for="PASSDM" class="label_pw nHide">비밀번호</label>
# 								<label for="PASSDM" id="lb_passdm" class="label_pw nHide">비밀번호</label>
# 								<input type="text" name="PASSDM" id="PASSDM" value="비밀번호" maxlength="20" class="input_pw" readonly="readonly" />
#                                 <label for="PASSWD" id="lb_passwd" class="label_pw nHide">비밀번호</label>
#                                 <input type="password" name="PASSWD" id="PASSWD" class="input_pw" maxlength="20" style="display:none;ime-mode:disabled;" onblur="vBlurPassInput();" enc="on" />
#
# 								<span class="option01"><input type="checkbox" id="keeplogin" name="keeplogin" class="chk_saveid" onmousedown="nc('NCM94');" onclick="isKeepLogin('on')" /> <label for="keeplogin" class="set_saveid" onmousedown="nc('NCM94');">로그인 유지</label> <i class="bar">|</i> <a href="javascript:xXecurePop.openWin(3);" class="ip" onmousedown="nc('NLI15');" title="새창 열림">IP보안 <strong id="ipLevelText">ON</strong></a></span>
# 								<input type="submit" name="btnLOGIN" id="btnLOGIN" value="로그인" class="icon_login" onkeydown="vkeydownSubmit(event);" />
# 								<span class="option02"><a href="javascript:onclick_Find();" title="아이디 찾기">아이디</a> / <a href="javascript:onclick_FindPW();" title="비밀번호 찾기">비밀번호 찾기</a> <i class="bar">|</i> <a href="javascript:onclick_Join();" title="회원가입"><strong>회원가입</strong></a> </span>
#
# 								<script type="text/javascript">
#                                 //<![CDATA[
#                                     initLogin();
#                                     nateLogin = new NateLogin('f_login', 'btnLOGIN', 'xo.nate.com/servlets/EncLoginServlet', loginBoxName, '비밀번호');
#                                 //]]>
#                                 </script>
# 							</fieldset>
# 						</form>
#                         <div id="layerXKDisabled" class="overlay_info type_security" style="display: none">
#                         <div class="layer_content"></div>
#                         </div>
#
# 						<div class="overlay_info nHide" id="divNateOn">
# 							<p>웹 네이트온 로그인은 설치가 필요 없는<br />가벼운 네이트온이 네이트 로그인 만으로<br />함께 로그인 되는 편리한 기능입니다.</p>
# 							<a href="//nateonweb.nate.com/nateon/download_web.php" onmousedown="nc('NLI75')" title="웹 네이트온이란?">웹 네이트온이란?</a>
# 							<button type="button" value="알림 레이어 닫기" title="알림 레이어 닫기" class="close" onclick="closeWebNateOnInfo()">알림 레이어 닫기</button>
# 						</div>
# 						<div class="overlay_info type_saveid nHide">
# 							<p>개인정보 보호를 위해<br>개인PC에서만<br>사용해 주세요. <a href="https://helpdesk.nate.com/web/faq-detail?faqId=KNOW0000000038&subNodeId=NODE0000000006&keyword=%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9C%A0%EC%A7%80&pageNo=1" onmousedown="nc('NLI33');" target="_blank" title="도움말보기">도움말보기 <i class="icon_arrow_right_red"></i></a></p>
# 							<button type="button" value="알림 레이어 닫기" title="알림 레이어 닫기" class="icon_x_black" onmousedown="nc('NLI32');" onclick="closeKeepLoginLayer()">알림 레이어 닫기</button>
# 						</div>
# 				</div>
#
#
# 				<hr />
# 				<h2>컨텐츠 영역</h2>
# 				<div id="news_area" class="area_news">
#
#
#
#
#
#
# <h3>뉴스</h3>
# <div class="menu" id="newsTabMenu">
# 	<h4 id="newstab1" class="menu01 on"><a href="//news.nate.com/" title="뉴스탭 열기" onclick="newsBox.clickTabLink('tab1_set1');return false;">뉴스</a></h4>
# 	<h4 id="newstab2" class="menu02"><a href="//sports.news.nate.com/" title="스포츠탭 열기" onclick="newsBox.clickTabLink('tab2_spo');return false;">스포츠</a></h4>
# 	<h4 id="newstab3" class="menu03"><a href="//news.nate.com/ent/section?mid=e0100;" title="연예탭 열기" onclick="newsBox.clickTabLink('tab3_ent');return false;">연예</a></h4>
#
# 	<h4 id="newstab4" class="menu04" style="display:none;"></h4>
# 	<h4 id="newstab5" class="menu05"><a href="//news.nate.com/rank/?mid=n1000" title="랭킹뉴스탭 열기" onclick="newsBox.clickTabLink('tab5_ranking');return false;">랭킹뉴스</a></h4>
# </div>
# <div class="content type_news" id="newsContType" onfocusin="newsBox.rollingStop();" onfocusout="newsBox.rollingStart();">
# 	<div class="tabCnt">
#
#
# 			<div class="rankBox" id="div_rank_sisa"></div>
# 			<div class="rankBox" id="div_rank_spo"></div>
# 			<div class="rankBox" id="div_rank_ent"></div>
# 			<ul class="type_thumb type02" id="newsImg_ul_1">
#
# 					<li id="newsImg0">
#
# 						<a href="//sports.news.nate.com/abrbaseball/photo?page=1&cid=1027583&fix=1027583" target="_self" onclick="setTabInfo();ndrclick('MEF09', 'NH_02_01_01-20231208095007');">
# 							<em class="icon slide">슬라이드</em>
#
# 							<span class="thumb_img"><img src="//news.nateimg.co.kr/etc/cms/2023/12/08/1701986179_893.jpg" alt="" width="168" /></span>
# 							<span class="txt">&quot;김하성이 상습폭행&quot; 신분 밝히고 사진 공개한 임혜동</span>
# 						</a>
# 					</li>
#
# 					<li id="newsImg1">
#
# 						<a href="//ps.news.nate.com/photo/slideShow?cid=1027629" target="_self" onclick="setTabInfo();ndrclick('MEF10', 'NH_01_01_02-20231208100707');">
# 							<em class="icon slide">슬라이드</em>
#
# 							<span class="thumb_img"><img src="//news.nateimg.co.kr/etc/cms/2023/12/08/1701997560_162.png" alt="" width="168" /></span>
# 							<span class="txt">어린이 감기환자로 긴 줄 이어진 병원</span>
# 						</a>
# 					</li>
#
#
#
# 					<li id="newsImg2">
# 						<a href="//ps.news.nate.com/photo/slideShow?cid=1027637&mid=e0102" target="_self" onclick="setTabInfo();ndrclick('MEF11', 'NH_03_01_03-20231208104216');">
# 							<em class="icon slide">슬라이드</em>
#
# 							<span class="thumb_img"><img src="//news.nateimg.co.kr/etc/cms/2023/12/08/1701999689_936.jpg" width="168" alt="" /></span>
# 							<span class="txt">김희정, 프라하에서 뽐낸 우아한 톤온톤 스타일링</span>
# 						</a>
# 					</li>
#
# 			</ul>
# 			<ul class="type_text" id="newsTxt_ul_1">
#
# 					<li id="newsTxt_li_0"><strong><a href="//news.nate.com/section?mid=n0300&n=1027506#cid1027506" target="_self" onclick="setTabInfo();ndrclick('MEB55', 'NH_01_02_02-20231208061321');">&quot;집값은 4200만원 떨어지고 갚을 돈은 늘고&quot;…수도권 자산 '뚝'</a></strong></li>
#
#
# 					<li id="newsTxt_li_1"><a href="//news.nate.com/hissue/clstList?mid=n0208&isq=11000&n=1027619#cid1027619" target="_self" onclick="setTabInfo();ndrclick('MEB57', 'NH_01_02_08-20231208094131');">강도형 해수부 장관 후보자, 음주·폭력 전과</a></li>
#
#
# 					<li id="newsTxt_li_2"><a href="//news.nate.com/hissue/clstList?mid=n0412&isq=11001&n=413202#cid413202" target="_self" onclick="setTabInfo();ndrclick('MEB59', 'NH_01_02_09-20231208095959');">아파트 층간소음 못잡으면 준공 승인 못받는다</a></li>
#
#
# 					<li id="newsTxt_li_3"><a href="//sports.news.nate.com/hissue/groupList?mid=s0106&isq=10617&sisq=10352&n=1027424#cid1027424" target="_self" onclick="setTabInfo();ndrclick('MEB61', 'NH_02_02_02-20231208061546');">'4억' 합의금 줬다는데…김하성, '상습 폭행vs공갈 협박' 진실공방에 휘말리다</a></li>
#
#
# 					<li id="newsTxt_li_4"><a href="//news.nate.com/ent/subsection?mid=e1100&n=1027633#cid1027633" target="_self" onclick="setTabInfo();ndrclick('MEC71', 'NH_03_02_01-20231208095427');">율희가 애들 버리고 도망쳤나요…과도한 '궁예질'은 삼가할 때</a></li>
#
#
#
# 			</ul>
# 			<ul class="type_text" id="newsTxt_ul_2">
#
# 					<li id="newsTxt_li_5"><a href="//news.nate.com/view/20231208n07786" target="_self" onclick="setTabInfo();ndrclick('MEF22', 'NH_01_02_15-20231208100945');">첫째만 편애하더니…&quot;둘째는 네가 키워&quot; 남편의 별거 선언</a></li>
#
#
# 					<li id="newsTxt_li_6"><strong><a href="//news.nate.com/hissue/clstList?mid=n0412&isq=10201" target="_self" onclick="setTabInfo();ndrclick('MEF24', 'NH_01_02_08-20231208102539');">이재명 19%, 한동훈 16%…차기 대선 첫 오차범위 내</a></strong></li>
#
#
# 					<li id="newsTxt_li_7"><a href="//sports.news.nate.com/hissue/clstList?mid=s0406&isq=8249&n=573874#cid573874" target="_self" onclick="setTabInfo();ndrclick('MEF26', 'NH_02_02_06-20231208092945');">포스테코글루 &quot;공격과 수비, 다 끔찍…SON 몸 상태는 몰라&quot;</a></li>
#
#
# 					<li id="newsTxt_li_8"><a href="//news.nate.com/view/20231208n02845" target="_self" onclick="setTabInfo();ndrclick('MEF28', 'NH_02_02_06-20231208064328');">'보류권 풀어달라' LG 부탁 거절하더니, MVP의 전격 복귀, 최강 외인 트리오 완성하다</a></li>
#
#
# 					<li id="newsTxt_li_9"><a href="//news.nate.com/view/20231208n04494" target="_self" onclick="setTabInfo();ndrclick('MEF30', 'NH_03_02_02-20231208100733');">다니엘, '2년 열애' 韓 여성과 오늘(8일) 결혼…사회 전현무</a></li>
#
#
# 			</ul>
#
#
#
# 					<ul class="type_text" id="newsTxt_ul_3">
#
# 							<li id="newsTxt_li_10"><a href="//news.nate.com/hissue/clstList?mid=n0508&isq=11051&n=1019436#cid1019436" target="_self" onclick="setTabInfo();ndrclick('MEB63', 'NH_01_02_08-20231208084124');">속옷차림으로 체포된 남성들…&quot;투항한 하마스 대원 가능성&quot;</a></li>
#
#
# 							<li id="newsTxt_li_11"><strong><a href="//news.nate.com/hissue/clstList?mid=n0208&isq=11000&n=1022666#cid1022666" target="_self" onclick="setTabInfo();ndrclick('MEB65', 'NH_01_02_08-20231208102423');">조희대 대법원장 후보 임명동의서 채택…오늘 본회의 표결</a></strong></li>
#
#
# 							<li id="newsTxt_li_12"><a href="//news.nate.com/hissue/clstList?mid=n0309&isq=11002&n=930057#cid930057" target="_self" onclick="setTabInfo();ndrclick('MEB67', 'NH_01_02_08-20231208095456');">'루나 폭락' 권도형 결국 미국行…&quot;최대 100년 이상 선고 가능&quot;</a></li>
#
#
# 							<li id="newsTxt_li_13"><a href="//sports.news.nate.com/hissue/clstList?mid=s0106&isq=8588&n=763425#cid763425" target="_self" onclick="setTabInfo();ndrclick('MEB69', 'NH_02_02_08-20231208080751');">NC 손아섭 보며 고개 끄덕인 한화 노시환 &quot;선배는 천재예요&quot;</a></li>
#
#
# 							<li id="newsTxt_li_14"><a href="//news.nate.com/ent/idolHissue?mid=e0608&hissueSq=10098&n=1027603#cid1027603" target="_self" onclick="setTabInfo();ndrclick('MEC73', 'NH_03_02_03-20231208093611');">워터밤 여신 권은비, 日서 영화배우 데뷔…'스마트폰을 떨어뜨렸을 뿐인데' 주인공</a></li>
#
#
# 					</ul>
# 					<ul class="type_thumb type01 nHide" id="newsImg_ul_2">
#
# 							<li id="newsImg3"></li>
#
# 							<li id="newsImg4"></li>
#
# 					</ul>
#
#
#
#
#
#
# 			<div id="newsPlusLayer" class="overlay_plus type01" style="display:none">
# 				<div class="plus_content">
# 					<iframe id="newsIfr" width="304" height="470" scrolling="no" frameborder="0" title="뉴스플러스 아이프레임" src="about:blank"></iframe>
# 					<button type="button" value="뉴스플러스 레이어 닫기" title="뉴스플러스 레이어 닫기" class="close" onclick="closeNewsPlus();ndrclick('MEC49','');">뉴스플러스 레이어 닫기</button>
# 				</div>
# 			</div>
#
# 	</div>
# 	<div class="bizCnt">
# 		<div class="isKeyword">
# 			<h4>실시간 이슈 키워드</h4>
# 			<ol class="isKeywordList" id="olLiveIssueKeyword">
#
#
#
# 							<li>
# 								<span class="num_rank">6</span>
# 								<a href="https://news.nate.com/search?q=투항한 하마스 가능성" onclick="newsBox.clickSearchKeyword('투항한 하마스 가능성');return false;" class="ik" onmousedown="nc('MEH21')">
# 									<span class="txt_rank">투항한 하마스 가능성</span>
#
#
#
#
#
# 											<span class="fc new"><span class="nHide">new</span></span>
#
#
# 								</a>
# 							</li>
#
# 							<li>
# 								<span class="num_rank">7</span>
# 								<a href="https://news.nate.com/search?q=정국 레코드협회 플래티넘" onclick="newsBox.clickSearchKeyword('정국 레코드협회 플래티넘');return false;" class="ik" onmousedown="nc('MEH22')">
# 									<span class="txt_rank">정국 레코드협회 플래티넘</span>
#
#
#
# 											<span class="fc down"><span class="nHide">하락</span>1</span>
#
#
#
#
# 								</a>
# 							</li>
#
# 							<li>
# 								<span class="num_rank">8</span>
# 								<a href="https://news.nate.com/search?q=고원희" onclick="newsBox.clickSearchKeyword('고원희');return false;" class="ik" onmousedown="nc('MEH23')">
# 									<span class="txt_rank">고원희</span>
#
#
#
#
# 											<span class="fc same"><span class="nHide">동일</span></span>
#
#
#
# 								</a>
# 							</li>
#
# 							<li>
# 								<span class="num_rank">9</span>
# 								<a href="https://news.nate.com/search?q=경상수지 68억달러 흑자" onclick="newsBox.clickSearchKeyword('경상수지 68억달러 흑자');return false;" class="ik" onmousedown="nc('MEH24')">
# 									<span class="txt_rank">경상수지 68억달러 흑자</span>
#
#
#
#
# 											<span class="fc same"><span class="nHide">동일</span></span>
#
#
#
# 								</a>
# 							</li>
#
# 							<li>
# 								<span class="num_rank">10</span>
# 								<a href="https://news.nate.com/search?q=수능 성적표" onclick="newsBox.clickSearchKeyword('수능 성적표');return false;" class="ik" onmousedown="nc('MEH25')">
# 									<span class="txt_rank">수능 성적표</span>
#
#
#
#
#
# 											<span class="fc new"><span class="nHide">new</span></span>
#
#
# 								</a>
# 							</li>
#
#
#
#
#
# 			</ol>
# 			<form id="frmKeyword" name="frmKeyword" action="https://news.nate.com/search" accept-charset="euc-kr" onsubmit="return false">
# 				<input type="hidden" id="bizq" name="q" value="" />
# 			</form>
# 		</div>
# 		<div class="adBox"></div>
# 		<div class="todayBox" id="divBox">
#
#
#
# 					<a href="https://nateonweb.nate.com/teamroom/" class="cmBox2" target="_self">
# 						<span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/11/1699343582958.png" width="168" height="138" alt=" 네이트온 팀룸" onmousedown="nc('MEH15');" /></span>
# 					</a>
#
#
#
# 		</div>
# 	</div>
# 	<dl class="content_recommend">
# 		<dt id="dtNewsRecomm"><em>뉴스</em></dt>
# 		<dd id="newsRecommend">
#
#
#
#
# 						<a href="//news.nate.com/comment?mid=n1500" onmousedown="nc('MEF42');setTabInfo();">투데이베플</a>
#
# 						<a href="//news.nate.com/ent/idol24" onmousedown="nc('MEF43');setTabInfo();">아이돌24시</a>
#
# 						<a href="//news.nate.com/hissue/clstList?mid=e0103&isq=7376" onmousedown="nc('MEF44');setTabInfo();">드라마 모아보기</a>
#
# 						<a href="//news.nate.com/hissue/clstList?mid=e0103&isq=7377" onmousedown="nc('MEF45');setTabInfo();">예능 모아보기</a>
#
#
#
# 		</dd>
# 	</dl>
#
#
#
# </div>
#
# <div class="nav" id="newsOptBtn">
# 	<span id="newsMoreArea"><em>3</em> / 6</span>
# 	<button id="newsRollingBtn" type="button" onclick="newsBox.changeRolling();" value="자동전환기능 정지" title="자동전환기능 정지" class="pause">자동전환기능 정지</button>
# 	<button type="button" onclick="ndrclick('MEC42');newsBox.showPreNext('P');" value="이전 뉴스 보기" title="이전 뉴스 보기" class="prev">이전 뉴스 보기</button>
# 	<button type="button" onclick="ndrclick('MEC43');newsBox.showPreNext('N');" value="다음 뉴스 보기" title="다음 뉴스 보기" class="next">다음 뉴스 보기</button>
# </div>
# <div id="newsNotice"></div>
#
# 					<div class="overlay_ticker" id="ticker_lyr" style="display:none">
# 						<div class="ticker_content">
# 							<iframe id="ticker_ifm" width="728" scrolling="no" height="318" frameborder="0" title="티커 아이프레임" src="about:blank"></iframe>
# 							<button type="button" value="티커 닫기" title="티커 닫기" class="close" onclick="nateonTickerClose();">티커 닫기</button>
# 						</div>
# 					</div>
# 				</div>
#
#
# 				<script type="text/javascript">
# 				//<![CDATA[
# 					loadSpecialBiRolling();
# 				//]]>
# 				</script>
#
#
# 				<!-- tiles:insertAttribute name="NateQ" /-->
#
#
#
#
#
# <div id="divContentsUpper" class="area_contents">
# 	<h3>컨텐츠</h3>
# 	<div class="menu">
# 		<h4 class="menu01"><a href="//pann.nate.com/talk/ranking" onclick="objPannArea.clickTab(0);return false;" title="Top랭킹" onmousedown="nc('PAN60')">Top랭킹</a></h4>
# 		<h4 class="menu02"><a href="//pann.nate.com/talk/c20025" onclick="objPannArea.clickTab(1);return false;" title="결시친" onmousedown="nc('PAN61')">결시친</a></h4>
# 		<h4 class="menu03"><a href="//pann.nate.com/talk/c20038" onclick="objPannArea.clickTab(2);return false;" title="10대톡" onmousedown="nc('PAN62')">10대톡</a></h4>
# 		<h4 class="menu04"><a href="//pann.nate.com/talk/c20028" onclick="objPannArea.clickTab(3);return false;" title="연예톡" onmousedown="nc('PAN63')">연예톡</a></h4>
# 		<h4 class="menu05 on"><a href="//pann.nate.com/talk/c20019" onclick="objPannArea.clickTab(4);return false;" title="회사톡" onmousedown="nc('PAN64')">회사톡</a></h4>
# 	</div>
# 	<div class="content" id="pannList">
#
#
#
# 		<ul class="ctList">
#
#
# 			<!-- 썸네일 있는 경우 -->
# 			<li class="type_thumb">
# 				<a href="https://pann.nate.com/talk/371555598" class="" onmousedown="nc('PAO61');objPannArea.clickContents(5);">
# 					<span class="thumb"><img src="https://thumb.pann.com/tc_110x70/http://fimg5.pann.com/new/download.jsp?FileID=67096920" width="105" height="66" alt="" /></span>
# 					<span class="title">“2차 가기 싫어 도망가는 대리 표정”…윤석열에 의해서 도망가고 싶은 이재용...</span>
#
# 					<em class="emph"><span class="nHide">댓글수</span>(21)</em>
#
# 				</a>
# 			</li>
#
#
#
#
#
# 			<!-- 썸네일 없는 경우 -->
# 			<li class="type_text">
# 				<a href="https://pann.nate.com/talk/371556398" onmousedown="nc('PAO62');objPannArea.clickContents(5);">
#                     <div class="list_box">
#
#                         <span class="emph"><span class="nHide">댓글수</span>(43)</span>
#
#                         <span class="link">퇴사 했는데 자꾸 붙잡아요</span>
#                     </div>
# 					<div class="desc">안녕하세요퇴사한지 6일정도 된 백수 입니다제 후임으로 신입을 뽑았고(완전 일에 대해서 잘 모르는 사람입니다)OT라는 식으로 2일동안 1시간씩 인수...</div>
# 				</a>
# 			</li>
#
#
#
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(37)</span>
#
# 					<a href="https://pann.nate.com/talk/371556428" class="link" onmousedown="nc('PAO63');objPannArea.clickContents(5);">하루종일 일 안하고 카톡하는 직원</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(39)</span>
#
# 					<a href="https://pann.nate.com/talk/371553925" class="link" onmousedown="nc('PAO64');objPannArea.clickContents(5);">첫 출근 대놓고 부모님 집값 확인하는 회사</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(15)</span>
#
# 					<a href="https://pann.nate.com/talk/371558481" class="link" onmousedown="nc('PAO65');objPannArea.clickContents(5);">거래처 사람이랑 얼마나 친해???</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(10)</span>
#
# 					<a href="https://pann.nate.com/talk/371557197" class="link" onmousedown="nc('PAO66');objPannArea.clickContents(5);">피해망상자들 옆에서 속닥되면 자기얘기하는 줄 앎</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(8)</span>
#
# 					<a href="https://pann.nate.com/talk/371553811" class="link" onmousedown="nc('PAO67');objPannArea.clickContents(5);">“기술을 배워라 접어라, 남자 연봉 6천은 돼야” 미혼남녀 결혼 이상형 살펴보니</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(6)</span>
#
# 					<a href="https://pann.nate.com/talk/371554276" class="link" onmousedown="nc('PAO68');objPannArea.clickContents(5);">어떤 직원이 더 화나? 갑자기 궁금</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(5)</span>
#
# 					<a href="https://pann.nate.com/talk/371558951" class="link" onmousedown="nc('PAO69');objPannArea.clickContents(5);">개갈구는 직장동료</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(3)</span>
#
# 					<a href="https://pann.nate.com/talk/371560503" class="link" onmousedown="nc('PAO70');objPannArea.clickContents(5);">12년 회사생활 위기네요.. 유연하게 대처하는법 좀 알려주세요.</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(1)</span>
#
# 					<a href="https://pann.nate.com/talk/371553929" class="link" onmousedown="nc('PAO71');objPannArea.clickContents(5);">엑스포 실패 위로차, 부산 국제시장 찾은 尹, 이재용과 떡볶이,튀김,여행기념 시식</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(1)</span>
#
# 					<a href="https://pann.nate.com/talk/371560808" class="link" onmousedown="nc('PAO72');objPannArea.clickContents(5);">尹, 12일 이재용 삼성전자 회장과 네덜란드 여행 및 ASML 본사 방문</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(5)</span>
#
# 					<a href="https://pann.nate.com/talk/371562832" class="link" onmousedown="nc('PAO73');objPannArea.clickContents(5);">피해망상 관음증 직원</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(1)</span>
#
# 					<a href="https://pann.nate.com/talk/371559914" class="link" onmousedown="nc('PAO74');objPannArea.clickContents(5);">같이 일하는 상사가 짜증나요.</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(3)</span>
#
# 					<a href="https://pann.nate.com/talk/371557410" class="link" onmousedown="nc('PAO75');objPannArea.clickContents(5);">어떻게 해야할까요</a>
# 				</div>
# 			</li>
#
# 			<li>
# 				<div class="list_box">
#
# 					<span class="emph"><span class="nHide">댓글수</span>(1)</span>
#
# 					<a href="https://pann.nate.com/talk/371558871" class="link" onmousedown="nc('PAO76');objPannArea.clickContents(5);">피해망상  밀라나 에바 특</a>
# 				</div>
# 			</li>
#
# 		</ul>
#
#
# 	</div>
# 	<!-- nav -->
# 	<div class="nav">
# 		<span><a href="//pann.nate.com/" onmousedown="nc('PAN65')">판홈</a> <i>|</i> <em>5</em> / 5</span>
# 		<button type="button" value="이전 컨텐츠 보기" title="이전 컨텐츠 보기" class="prev" onmousedown="nc('PAN98')" onclick="objPannArea.clickButton('P');">이전 컨텐츠 보기</button>
# 		<button type="button" value="다음 컨텐츠 보기" title="다음 컨텐츠 보기" class="next" onmousedown="nc('PAN99')" onclick="objPannArea.clickButton('N');">다음 컨텐츠 보기</button>
# 	</div>
# 	<!-- //nav -->
# </div>
#
# 				<div id="divIssueUp" class="area_issue">
# 	<h3>키워드</h3>
# 	<div class="menu">
# 		<div class="keyword_list">
# 			<div class="list_top">
# 				<h4 class="menu08"><a href="javascript:issueContents.clickIssueUpNateTv(0)" onmousedown="nc('CTG08')">TV</a></h4>
# 				<h4 class="menu01"><a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CTG01');">여행/맛집</a></h4>
# 				<h4 class="menu02"><a href="javascript:issueContents.clickIssueUpCategory(2, 0)" onmousedown="nc('CTG02');">뷰티</a></h4>
# 				<h4 class="menu03"><a href="javascript:issueContents.clickIssueUpCategory(3, 0)" onmousedown="nc('CTG03');">푸드</a></h4>
# 				<h4 class="menu04"><a href="javascript:issueContents.clickIssueUpToonNBook()" onmousedown="nc('CTG09');">만화/웹툰</a></h4>
# 				<h4 class="menu05"><a href="javascript:issueContents.clickIssueUpCategory(5, 0)" onmousedown="nc('CTG05');">패션</a></h4>
# 				<h4 class="menu06 on"><a href="javascript:issueContents.clickIssueUpCategory(6, 0)" onmousedown="nc('CTG06');">라이프</a></h4>
# 				<h4 class="menu07" id="issueTabShopping"><a href="javascript:issueContents.clickIssueUpShopping()" onmousedown="nc('CTG07');">쇼핑</a></h4>
# 			</div>
# 		<div class="list_btm" id="divIssueKeyword">
# 			<h5 class="on"><a href="javascript:issueContents.clickIssueUpCategory(6, 0)" onmousedown="nc('CCA36');">세상 이런 일이!</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(6, 1)" onmousedown="nc('CCA37');">살고 싶은 집</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(6, 2)" onmousedown="nc('CCA38');">반려 식물</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(6, 3)" onmousedown="nc('CCA39');">네이트뷰</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(6, 4)" onmousedown="nc('CCA40');">일상다반사</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(6, 5)" onmousedown="nc('CCA41');">꿀팁 모음집</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(6, 6)" onmousedown="nc('CCA42');">주방 부엌</a></h5></div>
# 		</div>
# 	</div>
# 	<div id="divIssueUpContents" class="content">
# <ul><li><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20231024n08302', 'N', 6, 0);" onmousedown="nc5('CBJ01','56577','70','1');nc2('CAF01');"><span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701754128965.jpg" width="169" height="126" alt="" /></span><span class="title"><strong>세계 최장수 개</strong><br /><strong>31년간 생존 비결</strong></span></a><cite>라이프</cite></li><li><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20230913n21563', 'N', 6, 0);" onmousedown="nc5('CBJ02','56577','70','2');nc2('CAF01');"><span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701404662923.jpg" width="169" height="126" alt="" /></span><span class="title">춘천에서 포착된<br />신기한 구름</span></a><cite>라이프</cite></li><li><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20231118n04631', 'N', 6, 0);" onmousedown="nc5('CBJ03','56577','70','3');nc2('CAF01');"><span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701404628742.jpg" width="169" height="126" alt="" /></span><span class="title"><strong>100만분의 1 확률로</strong><br /><strong>'중복 자궁' 임신?</strong></span></a><cite>라이프</cite></li><li class="type_text"><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20231124n10886', 'N', 6, 0);" onmousedown="nc5('CBJ04','56577','70','4');nc2('CAF01');"><span class="title">최소 천 년 전에<br />매장된 미라 발굴<br /></span><span class="content">지역 개발을 위해<br />쓰레기 치우던<br />과정 중 발견</span></a><cite>라이프</cite></li><li><a href="javascript:;" onclick="issueContents.clickContents('https://view.nate.com/tech/view/63219/', 'N', 6, 0);" onmousedown="nc5('CBJ05','56577','70','5');nc2('CAF01');"><span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701404618134.jpg" width="169" height="126" alt="" /></span><span class="title"><strong>세계적 미스터리</strong><br /><strong>4종 또다시 발견?</strong></span></a><cite>라이프</cite></li><li><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20231028n08819', 'N', 6, 0);" onmousedown="nc5('CBJ06','56577','70','6');nc2('CAF01');"><span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701404657719.jpg" width="169" height="126" alt="" /></span><span class="title"><strong>'골골송' 하나로</strong><br /><strong>세계 기록 등재!</strong></span></a><cite>라이프</cite></li><li class="type_text"><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20231031n32328', 'N', 6, 0);" onmousedown="nc5('CBJ07','56577','70','7');nc2('CAF01');"><span class="title">하늘에서 뿌리는<br />진짜 돈벼락 느낌?<br /></span><span class="content">4,000여 명 몰려<br />정신 없이 줍는<br />진풍경 생긴 이유</span></a><cite>라이프</cite></li><li><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20231001n01408', 'N', 6, 0);" onmousedown="nc5('CBJ08','56577','70','8');nc2('CAF01');"><span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701757813736.jpg" width="169" height="126" alt="" /></span><span class="title">같은 날에 태어나<br />기적이 된 세 자매</span></a><cite>라이프</cite></li><li class="type_wide"><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20231201n12410', 'N', 6, 0);" onmousedown="nc5('CBJ09','56577','70','9');nc2('CAF01');" ><span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701404632652.jpg" width="356" height="126" alt="" /></span><span class="title">세계에서 가장 긴 머리카락 236cm<br />기록 세운 '인도의 라푼젤'</span></a><cite>라이프</cite></li><li><a href="javascript:;" onclick="issueContents.clickContents('https://news.nate.com/view/20231108n20122', 'N', 6, 0);" onmousedown="nc5('CBJ10','56577','70','10');nc2('CAF01');"><span class="thumb"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701404636184.jpg" width="169" height="126" alt="" /></span><span class="title"><strong>최소 2년간 홀로</ ...
# 	<div class="content type_err nHide" id="emergencyLayer">
# 		<h4 class="">쇼핑탭 점검중</h4>
# 		<p>불편을 드려 죄송합니다.<br />더 좋은 서비스를 위해<br /><strong>쇼핑탭은 지금 점검</strong> 중입니다.</p>
# 		<a href="https://shopping.nate.com/">네이트 쇼핑으로 바로가기</a>
# 	</div>
# 	<div class="overlay_ally" style="display:none;"></div>
# 	<div class="movplay" id="movieSec">
# 		<div class="issuemov">
# 			<div id="divPlayer"></div>
# 			<a id="movieDetailLink" href="" class="btn_view_detail" title="광고 자세히보기" target="" onmousedown="javascript:nc('MVA02');">광고 자세히보기</a>
# 			<button type="button" value="동영상 플레이 레이어 닫기" title="동영상 플레이 레이어 닫기" class="btn_x_small_white" onclick="issueContents.closeMovie();" onmousedown="nc('CZA02')">동영상 플레이 레이어 닫기</button>
# 		</div>
# 		<span class="shadow"></span>
# 	</div>
# 	<div class="content type_err tbe nHide" id="divToonNBookErrLayer">
# 		<h4 class="">만화/웹툰탭 점검중</h4>
# 		<p>불편을 드려 죄송합니다.<br />더 좋은 서비스를 위해<br /><strong>만화/웹툰탭은 지금 점검</strong> 중입니다.</p>
# 		<a href="https://toonnbook.nate.com">네이트 툰앤북으로 바로가기</a>
# 	</div>
# </div>
#
#
#
#
#
#
#
# <div class="area_best">
#
# 	<h3>베스트 컨텐츠</h3>
#     <h4>당신이 놓친 오늘의<br>추천 콘텐츠</h4>
# 	<ul>
#
#
#
#
# 			<li>
# 			<a href="https://view.nate.com/enter/view/96899/" title="정우성이 최근 밥을 많이 사 준 후배?" onmousedown="nc('RCM01');">
# 					<span class="thumb">
# 						<img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701661508152.jpg"
# 						width="94" height="70" alt="정우성이 최근 밥을 많이 사 준 후배?" /></span>
# 						<span class="title">
# 						정우성이 최근 밥을 많이 사 준 후배?
# 						</span>
# 						<cite>
# 						 스타
# 						</cite>
# 			</a>
# 			</li>
#
#
#
#
# 			<li>
# 			<a href="https://view.nate.com/travel/view/90872/" title="차갑게 먹어도 맛난 어묵볶음 레시피" onmousedown="nc('RCM02');">
# 					<span class="thumb">
# 						<img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701660551700.jpg"
# 						width="94" height="70" alt="차갑게 먹어도 맛난 어묵볶음 레시피" /></span>
# 						<span class="title">
# 						차갑게 먹어도 맛난 어묵볶음 레시피
# 						</span>
# 						<cite>
# 						 푸드
# 						</cite>
# 			</a>
# 			</li>
#
#
#
#
# 			<li>
# 			<a href="https://news.nate.com/view/20231203n02317" title="단점을 찾을 수 없는 절정의 최근 미모" onmousedown="nc('RCM03');">
# 					<span class="thumb">
# 						<img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701660002956.jpg"
# 						width="94" height="70" alt="단점을 찾을 수 없는 절정의 최근 미모" /></span>
# 						<span class="title">
# 						단점을 찾을 수 없는 절정의 최근 미모
# 						</span>
# 						<cite>
# 						 스타
# 						</cite>
# 			</a>
# 			</li>
#
#
#
#
# 			<li>
# 			<a href="https://news.nate.com/view/20231130n12481" title="청순 여신의 색다른 파자마 룩 화보" onmousedown="nc('RCM04');">
# 					<span class="thumb">
# 						<img src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701661585502.jpg"
# 						width="94" height="70" alt="청순 여신의 색다른 파자마 룩 화보" /></span>
# 						<span class="title">
# 						청순 여신의 색다른 파자마 룩 화보
# 						</span>
# 						<cite>
# 						 스타
# 						</cite>
# 			</a>
# 			</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	</ul>
#
# </div>
#
#
#
#
#
#
# 				<div class="area_ranking">
# 					<h3>랭킹</h3>
# 					<div class="menu">
# 						<h4 class="menu01">Biz 추천검색어</h4>
# 					</div>
# 					<div class="content"  onmouseover="nateRanking.stopRolling()" onmouseout="nateRanking.startRolling()">
#
#
#
# 							<ul class="type_thumb">
#
# 									<li >
# 										<a href="https://search.daum.net/nate?w=tot&DA=NAD&q=프랜차이즈창업"  title="프랜차이즈 창업컨설팅" onmousedown="nc('RKM41')">
# 											<span class="thumb"><img src="//main.nateimg.co.kr/img/saImages/natemain_1700192965_2638.jpg" alt=""></span>
# 											<span class="text">프랜차이즈 창업컨설팅</span>
# 											<span class="desc">창업 순위와 시장 동향</span>
# 										</a>
# 									</li>
#
# 									<li >
# 										<a href="https://search.daum.net/nate?w=tot&DA=NAD&q=사무실이사"  title="사무실이사 가격비교" onmousedown="nc('RKM42')">
# 											<span class="thumb"><img src="//main.nateimg.co.kr/img/saImages/natemain_1700192967_4556.jpg" alt=""></span>
# 											<span class="text">사무실이사 가격비교</span>
# 											<span class="desc">사무실이사 비용 무료 견적</span>
# 										</a>
# 									</li>
#
# 									<li >
# 										<a href="https://search.daum.net/nate?w=tot&DA=NAD&q=근조화환"  title="고품격 근조화환" onmousedown="nc('RKM43')">
# 											<span class="thumb"><img src="//main.nateimg.co.kr/img/saImages/natemain_1700192966_75.jpg" alt=""></span>
# 											<span class="text">고품격 근조화환</span>
# 											<span class="desc">위로의 마음을 전하세요</span>
# 										</a>
# 									</li>
#
# 									<li class="commercial">
# 										<a href="http://tong-dal.com/" target="_blank" title="통신의달인" onmousedown="nc('RKM44')">
# 											<span class="thumb"><img src="//main.nateimg.co.kr/img/saImages/natemain_1673421214_4029.jpg" alt=""></span>
# 											<span class="text">통신의달인</span>
# 											<span class="desc">인터넷가입은 딱 통신의달인</span>
# 										</a>
# 									</li>
#
# 									<li class="commercial">
# 										<a href="https://www.etoos.com?_C_=92422549&utm_source=pc&utm_medium=nate&utm_campaign=2023_nate&utm_content=20231101_%EB%B9%84%EC%A6%88%EB%B0%94%EB%A1%9C%EA%B0%80%EA%B8%B0" target="_blank" title="이투스 2만2천원 구독하기" onmousedown="nc('RKM45')">
# 											<span class="thumb"><img src="//main.nateimg.co.kr/img/saImages/natemain_1700056572_8890.jpg" alt=""></span>
# 											<span class="text">이투스 2만2천원 구독하기</span>
# 											<span class="desc">모든인강 무제한 수강하기</span>
# 										</a>
# 									</li>
#
# 							</ul>
#
# 					</div>
# 					<div class="paging_slide">
# 						<span class="num_count_1"><em>2</em> / 2</span>
# 						<button type="button" class="btn prev" title="이전" onmousedown="nc('RKN98');" onclick="nateRanking.clickRankingBtn('P');">이전</button>
# 						<button type="button" class="btn next" title="다음" onmousedown="nc('RKN99');" onclick="nateRanking.clickRankingBtn('N');">다음</button>
# 					</div>
# 				</div>
#
# 				<hr />
# 				<h2>쇼핑&amp; 광고 영역</h2>
#
# 				<div class="area_shopping" id="shopping" style="display:none">
# 					<h3>쇼핑</h3>
#
#
#
#
#
# <div id="shopitemMall" class="mall1shop">
# 	<h3 id="mall1Title" class="tab"><a href="http://shopping.nate.com" class="link" onmousedown="ndrclick2('NFA01')" target="_top">쇼핑홈</a></h3>
# 	<div id="mall1Box" class="shopmall"></div>
# 	<h3 id="mall2Title" class="tab"><a href="#" class="link" onmousedown="ndrclick2('NFC01')" target="_blank"></a></h3>
# 	<div id="mall2Box" class="shopmall nHide"></div>
# 	<h3 id="mall3Title" class="tab"><a href="#" class="link" onmousedown="ndrclick2('NFE01')" target="_blank"></a></h3>
# 	<div id="mall3Box" class="shopmall nHide"></div>
# 	 <h3 id="mall4Title" class="tab"><a href="#" class="link" onmousedown="ndrclick2('NFG01')" target="_blank"></a></h3>
# 	<div id="mall4Box" class="shopmall nHide"></div>
# 	<div id="relShopping">
# 		<strong class="nHide">쇼핑 관련 리스트</strong>
# 		<div class="paging_slide">
# 			<button type="button" title="이전" id="shoppingPrev" class="btn prev" onmousedown="ndrclick2('NFZ01')">쇼핑 이전 내용</button>
# 			<button type="button" title="다음" id="shoppingNext" class="btn next" onmousedown="ndrclick2('NFZ02')">쇼핑 다음 내용</button>
# 		</div>
# 	</div>
# </div>
#
# <script type="text/javascript">
# //<![CDATA[
#     var nDt = new Date();
#     var verShop = '' + (nDt.getMonth()+1) + nDt.getDate() + nDt.getHours() + nDt.getMinutes();
# //]]>
# </script>
#
#
#
#                 </div>
#
# 				<div class="area_shopping type_err" id="shopping_err" style="display:none">
# 					<h4 class="">쇼핑박스 점검중</h4>
# 					<p>불편을 드려 죄송합니다.<br />더 좋은 서비스를 위해<br /><strong>쇼핑박스는 지금 점검</strong> 중입니다.</p>
# 					<a href="http://shopping.nate.com">네이트 쇼핑으로 바로가기</a>
# 				</div>
#
# 				<div class="area_shopping_today">
# 					<!-- tiles:insertAttribute name="shopRecommendation" /-->
# 				</div>
#
#
#
#
#
#
# 	<div id="divQuickMenu" class="area_quick">
# 	<h3>퀵링크</h3>
# 	<div class="area_sktad01"></div>
# 	<ul>
# 		<li class="totop"><a href="javascript:;" onmousedown="nc('RAB15');"><span>맨위로</span></a></li>
#
#
# 				<li>
#
#
# 					<a href="https://tv.nate.com/" title="네이트TV 서비스 가기"  onmousedown="nc('RAB25');">네이트TV</a>
# 				</li>
#
#
#
# 				<li>
#
#
# 					<a href="https://toonnbook.nate.com/" title="툰앤북 서비스 가기"  onmousedown="nc('RAB24');">툰앤북</a>
# 				</li>
#
#
#
# 				<li>
#
#
# 					<a href="https://mobile.nate.com/decorate/mvno/top" title="컬러링 서비스 가기"  onmousedown="nc('RAB19');">컬러링</a>
# 				</li>
#
#
#
# 				<li>
#
#
# 					<a href="http://editor.nate.com/" title="이슈UP추천 서비스 가기"  onmousedown="nc('RAB23');">이슈UP추천</a>
# 				</li>
#
#
# 		<li class="issue"><a href="javascript:;" onmousedown="nc('RAB08');">이슈<em class="issueup">UP</em></a></li>
# 	</ul>
# </div>
#
#
# 			</div>
# 			<hr />
#
#
#
#
#
#  <div id="footer">
# 	<h2>푸터 영역</h2>
# 	<div class="notice">
# 		<h3><a href="https://helpdesk.nate.com/web/notice/main" onmousedown="nc('NFT01');">공지사항</a></h3>
# 		<a href="https://helpdesk.nate.com/web/notice/main-detail?id=8806" onmousedown="nc('NFT02');">네이트 유료서비스 이용약관 개정 안내</a>
# 	</div>
# 	<dl>
# 		<dt>네이트 공용 푸터</dt>
# 		<dd>
# 			<a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT21');">회사소개</a> <span>|</span>
# 			<a href="http://business.nate.com/" onmousedown="nc('NFT29');">광고문의</a> <span>|</span>
# 			<a href="/policy/legal.html" onmousedown="nc('NFT24');">서비스 약관</a> <span>|</span>
# 			<a href="/policy/privacy.html" onmousedown="nc('NFT25');"><strong>개인정보처리방침</strong></a> <span>|</span>
# 			<a href="/policy/youthpolicy.html" onmousedown="nc('NFT26');">청소년보호정책</a> <span>|</span>
# 			<a href="http://helpdesk.nate.com/" onmousedown="nc('NFT11');">고객센터</a> <span>|</span>
# 			<span class="copyright">&copy; <a href="http://www.skcomms.co.kr/" target="_blank" onmousedown="nc('NFT41');"><strong><span class="sk">SK</span> Communications.</strong></a></span>
# 		</dd>
# 	</dl>
# 	<a href="/sitemap/index.html" class="view_all" onmousedown="nc('NFT12');">서비스 전체보기</a>
# </div>
# 			<hr />
# 			<div id="adContainer">
# 				<h2>광고 영역</h2>
# 				<div id="ad_layer1"  class="area_ad01"></div>
# 				<div id="ad_layer2" class="area_ad02">
# 				</div>
# 				<div class="area_adual">
# 					<div class="area_ad03">
# 					</div>
# 					<div class="area_ad04">
# 					</div>
# 				</div>
#
#
#
#
#
#
# <div class="area_ad05 nHide" id="leftAd05Cj">
# 	<a href="http://talkon.nate.com/service.html" onmousedown="nc('NBI11');" target="_blank"><img src="//main.nateimg.co.kr/img/v6/talkon_55x110.gif" width="55" height="110" alt="게임할땐 토크온!" /></a>
# </div>
#
# 				<div class="area_ad06"></div>
# 				<div class="area_sktad02"></div>
# 				<div class="area_ad09">
# 					<!-- iframe id="ifrm_ad09" name="ifrm_ad09" frameborder="0" width="728" height="90" scrolling="no" src="about:blank" title="광고"></iframe -->
# 				</div>
#
#
#
#
#
#
# <div class="area_ad10">
# 	<a href="https://www.cymera.com/main/ko" onmousedown="setNcCode('NAA21|NAA22',iSvcSeqC-1);"><img src="//main.nateimg.co.kr/img/cms/content_pool/2023/11/1699344089055.png" width="332" height="90" alt=" 싸이메라" /></a>
# </div>
#
#
# 			    <div id="ad_layer3"></div>
# 			    <div id="ad_layer4" style="display:none;"></div>
# 			</div>
# 		</div>
#
#
#
#
#
#
# <div id="cbContainer">
# 	<div id="cbLayer" class="area_ad08" style="display: none">
#
# 		<span class="commTxt">한눈에 보는 오늘 <em>NATE</em>와 함께 하루를 시작하세요.</span>
# 		<a href="javascript:;" title="NATE를 시작페이지로" id="cbLayerLink">NATE를 시작페이지로</a>
#
#
# 	</div>
# </div>
#
# 	</div>
#
# <div id="plus_footer" class="setting_moblie" style="display: none"></div>
# <span id="layerTemp"></span>
# <script type="text/javascript" src="/js/common/natead_081.js?v=20200206_02"></script>
#
# <script type="text/javascript">
#
# 	if (isiPad) {
# 		document.write('<img src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/ipad/]" width="0"  height="0" border="0" alt="" />');
# 	}
#
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# //<![CDATA[
# try{
#
# 	var contentsUpperTabMenu = ["null", "http://pann.news.nate.com/info", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_gray.gif", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_black.gif" ];
# 	var contentsUpperTopLink = [["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"]];
# 	var contentsUpperSecondPannTitle = ["톡커들의 선택"];
#
# }catch (e) { }
# //]]>
# </script>
#
# <!--natemain-->
#
#
#
# <script type="text/javascript">//<![CDATA[
#  CFN_type = ''; CFN_id = ''; CFN_cn = ''; CFN_cmn = ''; CFN_link = ''; CFN_link_id = ''; id = (CFN_type == 'N') ? CFN_id : CFN_link_id; cyid = (CFN_type == 'C') ? CFN_id : CFN_link_id; name = CFN_cn; isEmpas = ('' == '1'); refererDomain = ''; CFN_cust_tp_cd = ''; CFN_sex_cd = ''; loginType = ''; isMobile = 'F'; CFN_link_cust_tp_cd = ''; CFN_link_stat_cd = ''; var ndrLoginStatus = (isNateLogin) ? 'login' : ((bLogout) ? 'byebye' : 'logout'); try { divReferer(refererDomain); } catch (e) { } try { if (isNateLogin) fillPersonInfo();} catch (e) { } pageEnd('', '/');//]]>
# </script></body></html>

# %% [markdown]
# #### 문서에서 원하는 내용 추출하기(파싱)
# - html 문서(코드를 통해서 변수에 저장되어 있음)에서 원하는 내용 추출
#     - 필요한 내용만 추출
#     - BeautifulSoup 라이브러리 사용
#         - 태그 형식으로 된 text를 파싱할 때 사용
#     - find() / findAll() 등 함수 사용

# %% [markdown]
# #### BeautifulSoup
# - import bs4
# - 데이터를 추출하는데 필요한 기능이 들어 있는 라이브러리 (파싱 라이브러리)
# - 외부 라이브러리 : 설치해야 함
# - 주피터는 기본 패키지임(설치하지 않아도 됨)
# - 파이참 설치방법
#     - File/Settings
#     - Project Interpreter에서 bs4 검색
#     - [Install Package]

# %%
import bs4

# %%
url = 'https://www.nate.com'
html = urlopen(url)
html

# %% [markdown]
# - urlopen으로 소스코드 전달받은 경우에는
# - bs4에 response객체를 그대로 전달해도 파싱이 가능

# %%
#######
# 응답객체인 html을 BeautifulSoup(응답객체, 파서기) 함수에 전달
# bs4  파싱객체를 반환
bs_obj = bs4.BeautifulSoup(html,'html.parser')
# bs_obj 변수에는 소스코드와 파서기가 있고 bs4의 모듈을 사용할 수 있는 객체
type(bs_obj)
# Out:
# bs4.BeautifulSoup

# %%
# bs4.BeautifulSoup
print(bs_obj.prettify())
# html 소스코드를 들여쓰기 하여 계층적인 구조로 표현 (가독성이 높다)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="//www.nate.com/" name="msapplication-starturl"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="" name="nate:title"/>
#   <meta content="네이트 이슈UP" name="nate:description"/>
#   <meta content="네이트 홈" name="nate:site_name"/>
#   <meta content="https://www.nate.com/" name="nate:url"/>
#   <meta content="" name="nate:image"/>
#   <meta content="새로워진 nate에서 당신의 오늘을 만나보세요" name="description"/>
#   <meta content="한눈에 보는 오늘 : 네이트" property="og:title"/>
#   <meta content="https://www.nate.com/" property="og:url"/>
#   <meta content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" property="og:image"/>
#   <meta content="새로워진 nate에서 당신의 오늘을 만나보세요" property="og:description"/>
#   <title>
#    한눈에 보는 오늘 : 네이트
#   </title>
#   <link href="/css/common.min.css?v=202309201110_01" rel="stylesheet" type="text/css"/>
#   <link href="//main.nateimg.co.kr/img/v7/favicon_32.ico" rel="shortcut icon" type="image/x-icon">
#    <link href="//www.nate.com" rel="canonical"/>
#    <script src="/js/common/jquery-1.9.1.min.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     var isSvc = true; var isInfoAjax = true;
# 	var make = 't';
# 	var isMakeLogin = '';
# 	var host = 'www.nate.com';
# 	var isNateLogin = (isMakeLogin == "Y") ? true : false;
# 	var myId = "";
# 	var iSvcSeq  ='2';
# 	var iSvcSeqB ='2';
# 	var iSvcSeqC ='2';
# 	var currentWeatherIndex = [0,11,8];
# 	var iSvcSeqW = iSvcSeqB;
# 	var isCommsbarOpen = ('N' == 'Y') ? true : false;
# 	var loginType = '';
# 	var isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);
# 	var isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000
# 	var isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);
# 	var isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);
# 	if (isTablet)
# 	{
# 	    document.write('<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />');
# 	}
# 	var loginBoxName 	= "아이디 or @이하 모두 입력";
# 	var hostInfo 	 	= (host.length > 0) ? '//' + host : '';
#
# 	var verIssue01 		= '202312081102';
# 	var verIssue02 		= '202312081102';
# 	var verIssue03 		= '202312081102';
# 	var verIssue04 		= '202312081102';
# 	var verIssue05 		= '202312081102';
# 	var verIssue06 		= '202312081102';
# 	var verIssue07 		= '202312081102';
#
# 	var verNateTV		= '202312081103';
# 	var verIssueKeyword	= '202312081105';
# 	var verToonNBook	= '202312081047';
#
# 	var verNateQ01		= '202312081058';
# 	var verRanking06	= '202312081104';
#
# 	var verGnbRoll		= '202312081102';
# 	var verNewsBox 		= '202312081105';
# 	var verShopRecomm	= '202312081011';
# 	var verNateQ02		= '202312081105';
#
# 	var verPannTotal		= '202312081102';
# 	var verPannWomanLife	= '202312081102';
# 	var verPannTeens		= '202312081102';
# 	var verPannEnter		= '202312081103';
# 	var verTodayKeyword 	= '202312081103';
# 	var verWorkLife			= '202312081103';
# 	var verKeywordAd		= '202312081018';
# 	var verAdFunFun			= '202312081036';
# 	var verBizSearch 		= '202311171636';
# 	var verPann01 			= '201907240835';
# 	var verPann02 			= '201907240835';
#
# 	var shoppingInspection 		= 'N';
# 	var isEmergencyShoppingTab 	= 'N';
# 	var isAutoRefresh 			= true;
# 	var isChangeTab 			= false;
# 	var nateAwardsStat			= '';
# 	var isViewKeywordRank		= 'N';
# 	var isEmergencyToonNBookTab = 'N';
#
# 	//]]>
#    </script>
#    <script src="/js/common/nate_general_v20170627.js?v=202311061245_15" type="text/javascript">
#    </script>
#    <script src="/js/common/ac_v5.js?v=20221017_07" type="text/javascript">
#    </script>
#    <script src="/js/common/nate_logout_v20170627.js?v=202001141024_01" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     //<![CDATA[
# 			var bLogout = false;
# 	    	if (isLogout()) { fillLogout(); }
# 		 //]]>
#    </script>
#   </link>
#  </head>
#  <body>
#   <script type="text/javascript">
#    //<![CDATA[
# 		pageEnd2('st');
# 	 //]]>
#   </script>
#   <div id="mainContainer">
#    <div class="area_access">
#     <h2>
#      네이트 메인페이지 주요 내용 바로가기
#     </h2>
#     <ul>
#      <li>
#       <a href="#search">
#        <strong>
#         통합검색 바로가기
#        </strong>
#       </a>
#      </li>
#      <li>
#       <a href="#UI">
#        <strong>
#         로그인영역 바로가기
#        </strong>
#       </a>
#      </li>
#      <li>
#       <a href="#news_area">
#        <strong>
#         본문영역 바로가기
#        </strong>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div id="container">
#     <div id="header">
#      <div class="area_bi" id="NateBi" role="banner">
#       <h1 class="bi" title="네이트">
#        <a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">
#         네이트
#        </a>
#       </h1>
#      </div>
#      <div class="area_ignb" id="divignb">
#       <h2>
#        독립GNB
#       </h2>
#       <h3>
#        편리한 네이트
#       </h3>
#       <ul>
#        <li>
#         <a href="https://search.daum.net/nate?thr=sbma&amp;w=tot&amp;q=%EB%84%A4%EC%9D%B4%ED%8A%B8%EC%95%B1" onmousedown="nc('NBI04');">
#          네이트앱
#         </a>
#        </li>
#        <li>
#         <a href="//nateonweb.nate.com/" onmousedown="nc('NBI05');">
#          네이트온
#         </a>
#        </li>
#        <li>
#         <a href="http://www.cymera.com/main/ko" onmousedown="nc('NBI07');">
#          싸이메라
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="area_search" role="search">
#       <h2>
#        통합검색
#       </h2>
#       <form accept-charset="utf-8" action="https://search.daum.net/nate" id="search" name="search" onsubmit="return checkSearchForm()">
#        <input id="thr" name="thr" type="hidden" value="sbma"/>
#        <input id="w" name="w" type="hidden" value="tot"/>
#        <fieldset>
#         <legend>
#          통합검색 입력
#         </legend>
#         <div class="home" id="acWrap" onmouseover="ac_LoadByNateMain();">
#          <input autocomplete="off" class="type_text" id="q" name="q" onkeydown="return checkSearchQEnter(event)" onmousedown="clickSearchKeywordAd()" style="ime-mode:active" type="text" value=""/>
#          <input class="type_btn" id="acBtn" title="검색" type="submit"/>
#          <div id="acDiv" style="display:none;">
#          </div>
#         </div>
#        </fieldset>
#       </form>
#       <input id="premiumText" name="premiumText" title="" type="hidden" value="">
#        <input id="premiumLink" name="premiumLink" title="" type="hidden" value=""/>
#        <input id="statCode" name="statCode" title="" type="hidden" value=""/>
#        <div class="search_keyword">
#         <dl>
#          <dd>
#           <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%B6%94%EC%84%B1%ED%9B%88+%EC%A7%84%EA%B5%AC+%EB%8D%94+%EC%99%80%EC%9D%BC%EB%93%9C&amp;rtmaxcoll=DNS" id="onclick_semantic01" onmousedown="setNcCode('NSC11|NSC21|NSC31',iSvcSeq-1);">
#            추성훈 진구 확정
#           </a>
#           <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EB%8C%80%EB%9F%89%EB%AC%B8%EC%9E%90" id="onclick_semantic02" onmousedown="setNcCode('NSC12|NSC22|NSC32',iSvcSeq-1);">
#            단체문자저렴한곳
#           </a>
#           <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%96%B4%EB%A6%B0%EC%9D%B4%EB%B3%B4%ED%97%98" id="onclick_semantic03" onmousedown="setNcCode('NSC13|NSC23|NSC33',iSvcSeq-1);">
#            어린이보험 가입시기
#           </a>
#           <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%96%91%EC%A0%95%EC%9B%90+%EB%93%9D%EB%82%A8&amp;rtmaxcoll=DNS" id="onclick_semantic04" onmousedown="setNcCode('NSC14|NSC24|NSC34',iSvcSeq-1);">
#            양정원 득남
#           </a>
#           <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%9D%B4%EC%8A%B9%EB%AA%A8+17%EC%9D%BC+%EA%B2%B0%ED%98%BC&amp;rtmaxcoll=DNS" id="onclick_semantic05" onmousedown="setNcCode('NSC15|NSC25|NSC35',iSvcSeq-1);">
#            이승모 17일 결혼
#           </a>
#          </dd>
#         </dl>
#        </div>
#        <a class="link-ngpt" href="https://m.nate.com/aichat.html" onmousedown="nc('NNC01');" target="_blank">
#         AI챗 바로가기
#        </a>
#       </input>
#      </div>
#      <div class="area_gnb" id="divGnb" role="navigation">
#       <h2>
#        GNB
#       </h2>
#       <ul>
#        <li class="mail">
#         <a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">
#          메일
#         </a>
#        </li>
#        <li class="news">
#         <a href="//news.nate.com/" onmousedown="nc('NEV31');">
#          뉴스
#         </a>
#        </li>
#        <li class="pann">
#         <a href="https://pann.nate.com/" onmousedown="nc('NGB02');">
#          판
#         </a>
#        </li>
#        <li class="chat1">
#         <a href="https://m.nate.com/aichat.html" onmousedown="nc('NGB51');" target="_blank">
#          AI챗
#         </a>
#         <em class="beta">
#          beta
#         </em>
#        </li>
#        <li class="tv">
#         <a href="https://tv.nate.com/" onmousedown="nc('NGB43');">
#          TV
#         </a>
#        </li>
#        <li class="comics">
#         <a href="https://toonnbook.nate.com/" onmousedown="nc('NGB44');">
#          툰앤북
#         </a>
#        </li>
#        <li class="fortune">
#         <a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">
#          운세
#         </a>
#        </li>
#        <li class="game">
#         <a href="http://game.nate.com/" onmousedown="nc('NGB06');">
#          게임
#         </a>
#        </li>
#        <li class="shopping">
#         <a href="//shopping.nate.com/" onmousedown="nc('NGB17');">
#          쇼핑
#         </a>
#        </li>
#        <li class="teamroom">
#         <a href="https://nateonweb.nate.com/teamroom/" onmousedown="nc('NGB42');" title="함께하는 일이 쉬워진다">
#          팀룸
#         </a>
#        </li>
#        <li class="">
#         <a href="https://view.nate.com/" onmousedown="nc('NGB50');" title="네이트뷰">
#          네이트뷰
#         </a>
#        </li>
#        <li class="more">
#         <a href="javascript:;" id="aGnbMore" onmousedown="nc('NGB31');" title="전체 서비스 더보기">
#          더보기
#         </a>
#         <div class="list_svc" style="display:none">
#          <ul class="row_first">
#           <li>
#            <a href="//news.nate.com" onmousedown="nc('NSD30');">
#             <strong>
#              뉴스
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">
#             날씨
#            </a>
#           </li>
#           <li>
#            <a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">
#             스포츠
#            </a>
#           </li>
#           <li>
#            <a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">
#             연예
#            </a>
#           </li>
#           <li>
#            <a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">
#             아이돌24
#            </a>
#           </li>
#           <li>
#            <a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">
#             랭킹뉴스
#            </a>
#           </li>
#          </ul>
#          <ul class="row_second">
#           <li>
#            <a href="https://pann.nate.com/" onmousedown="nc('NSD68');">
#             <strong>
#              판
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">
#             톡톡
#            </a>
#           </li>
#           <li>
#            <a href="https://pann.nate.com/talk/imageTheme/index" onmousedown="nc('NSD08');">
#             판포토
#            </a>
#           </li>
#           <li>
#            <a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">
#             팬톡
#            </a>
#           </li>
#          </ul>
#          <ul class="row_third">
#           <li>
#            <a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">
#             네이트온
#            </a>
#           </li>
#           <li>
#            <a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">
#             네이트캐쉬
#            </a>
#           </li>
#           <li>
#            <a href="https://sms.nate.com/" onmousedown="nc('NSD35');">
#             문자메시지
#            </a>
#           </li>
#           <li>
#            <a href="https://mail.nate.com/pims/" onmousedown="nc('NSD34');">
#             주소록
#            </a>
#           </li>
#          </ul>
#          <ul class="row_fourth">
#           <li>
#            <a href="//mobile.nate.com/" onmousedown="nc('NSD41');">
#             컬러링
#            </a>
#           </li>
#           <li>
#            <a href="//editor.nate.com/" onmousedown="nc('NSD42');">
#             이슈UP추천
#            </a>
#           </li>
#          </ul>
#          <span>
#           <a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">
#            서비스 전체보기
#           </a>
#          </span>
#          <button onmousedown="nc('NSD95');" title="더보기 닫기" type="button" value="더보기 닫기">
#           더보기 닫기
#          </button>
#         </div>
#        </li>
#       </ul>
#      </div>
#      <div class="area_rtkwd type_alone" id="keywordRank">
#       <h3 class="nHide">
#        <a href="#" title="네이트 인기검색어로 이동">
#         실시간 검색어
#        </a>
#       </h3>
#      </div>
#      <div class="area_biz type_alone" id="bizRank">
#       <h3 class="nHide">
#        <a href="#" title="네이트 인기검색어로 이동">
#         비즈 검색어
#        </a>
#       </h3>
#      </div>
#      <div class="todayBox" id="divTodayKeywordArea" onmouseout="todayKeyword.startTodayKeyword()" onmouseover="todayKeyword.stopTodayKeyword()">
#       <div id="divTodayKeyword">
#        <a class="keyword" href="https://news.nate.com/?keyword_dtm=2023-12-08 10:49:43&amp;keyword_sq=75978" onmousedown="nc('TOD52');" title="속옷 차림으로 체포된 남성들">
#         속옷 차림으로 체포된 남성들
#        </a>
#       </div>
#       <div class="kwrd_slide">
#        <div class="today_tit">
#         <a href="https://news.nate.com/" onmousedown="nc('TOD61');">
#          <div class="logoimg">
#           <div class="circle step1">
#           </div>
#           <div class="circle step2">
#           </div>
#          </div>
#          <span class="svcname">
#           오늘
#          </span>
#         </a>
#        </div>
#        <button class="btn prev" id="Prev" onclick="todayKeyword.viewPreNext('P')" onmousedown="nc('TOD91');" title="이전" type="button">
#         <span>
#          오늘 키워드 이전 내용
#         </span>
#        </button>
#        <button class="btn next" id="Next" onclick="todayKeyword.viewPreNext('N')" onmousedown="nc('TOD92');" title="다음" type="button">
#         <span>
#          오늘 키워드 다음 내용
#         </span>
#        </button>
#       </div>
#      </div>
#     </div>
#     <hr/>
#     <div id="content">
#      <div class="area_auth" id="UI">
#       <h2>
#        회원 로그인 영역
#       </h2>
#       <script type="text/javascript">
#        //<![CDATA[
#                         document.write('<script type="text/javascript" src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2022111801"><\/script>');
#                     //]]>
#       </script>
#       <form action="https://xo.nate.com/LoginAuth.sk" id="f_login" method="post" name="f_login" onsubmit="return SubmitCheck();" target="_top">
#        <input id="redirect" name="redirect" type="hidden" value="https://www.nate.com/"/>
#        <input id="PASSWD_RSA" name="PASSWD_RSA" type="hidden" value=""/>
#        <input id="domain" name="domain" type="hidden" value="nate.com"/>
#        <input name="cpurl" type="hidden" value="www_ndr.nate.com%2Flogin%2F"/>
#        <fieldset>
#         <legend>
#          회원 로그인
#         </legend>
#         <label class="label_id nHide" for="ID">
#          아이디 or @이하 모두 입력
#         </label>
#         <input class="input_id" id="ID" name="ID" style="ime-mode:disabled;" title="아이디 or @이하 모두 입력" type="text" value=""/>
#         <label class="label_pw nHide" for="PASSDM">
#          비밀번호
#         </label>
#         <label class="label_pw nHide" for="PASSDM" id="lb_passdm">
#          비밀번호
#         </label>
#         <input class="input_pw" id="PASSDM" maxlength="20" name="PASSDM" readonly="readonly" type="text" value="비밀번호"/>
#         <label class="label_pw nHide" for="PASSWD" id="lb_passwd">
#          비밀번호
#         </label>
#         <input class="input_pw" enc="on" id="PASSWD" maxlength="20" name="PASSWD" onblur="vBlurPassInput();" style="display:none;ime-mode:disabled;" type="password"/>
#         <span class="option01">
#          <input class="chk_saveid" id="keeplogin" name="keeplogin" onclick="isKeepLogin('on')" onmousedown="nc('NCM94');" type="checkbox"/>
#          <label class="set_saveid" for="keeplogin" onmousedown="nc('NCM94');">
#           로그인 유지
#          </label>
#          <i class="bar">
#           |
#          </i>
#          <a class="ip" href="javascript:xXecurePop.openWin(3);" onmousedown="nc('NLI15');" title="새창 열림">
#           IP보안
#           <strong id="ipLevelText">
#            ON
#           </strong>
#          </a>
#         </span>
#         <input class="icon_login" id="btnLOGIN" name="btnLOGIN" onkeydown="vkeydownSubmit(event);" type="submit" value="로그인"/>
#         <span class="option02">
#          <a href="javascript:onclick_Find();" title="아이디 찾기">
#           아이디
#          </a>
#          /
#          <a href="javascript:onclick_FindPW();" title="비밀번호 찾기">
#           비밀번호 찾기
#          </a>
#          <i class="bar">
#           |
#          </i>
#          <a href="javascript:onclick_Join();" title="회원가입">
#           <strong>
#            회원가입
#           </strong>
#          </a>
#         </span>
#         <script type="text/javascript">
#          //<![CDATA[
#                                     initLogin();
#                                     nateLogin = new NateLogin('f_login', 'btnLOGIN', 'xo.nate.com/servlets/EncLoginServlet', loginBoxName, '비밀번호');
#                                 //]]>
#         </script>
#        </fieldset>
#       </form>
#       <div class="overlay_info type_security" id="layerXKDisabled" style="display: none">
#        <div class="layer_content">
#        </div>
#       </div>
#       <div class="overlay_info nHide" id="divNateOn">
#        <p>
#         웹 네이트온 로그인은 설치가 필요 없는
#         <br/>
#         가벼운 네이트온이 네이트 로그인 만으로
#         <br/>
#         함께 로그인 되는 편리한 기능입니다.
#        </p>
#        <a href="//nateonweb.nate.com/nateon/download_web.php" onmousedown="nc('NLI75')" title="웹 네이트온이란?">
#         웹 네이트온이란?
#        </a>
#        <button class="close" onclick="closeWebNateOnInfo()" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">
#         알림 레이어 닫기
#        </button>
#       </div>
#       <div class="overlay_info type_saveid nHide">
#        <p>
#         개인정보 보호를 위해
#         <br/>
#         개인PC에서만
#         <br/>
#         사용해 주세요.
#         <a href="https://helpdesk.nate.com/web/faq-detail?faqId=KNOW0000000038&amp;subNodeId=NODE0000000006&amp;keyword=%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9C%A0%EC%A7%80&amp;pageNo=1" onmousedown="nc('NLI33');" target="_blank" title="도움말보기">
#          도움말보기
#          <i class="icon_arrow_right_red">
#          </i>
#         </a>
#        </p>
#        <button class="icon_x_black" onclick="closeKeepLoginLayer()" onmousedown="nc('NLI32');" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">
#         알림 레이어 닫기
#        </button>
#       </div>
#      </div>
#      <hr/>
#      <h2>
#       컨텐츠 영역
#      </h2>
#      <div class="area_news" id="news_area">
#       <h3>
#        뉴스
#       </h3>
#       <div class="menu" id="newsTabMenu">
#        <h4 class="menu01 on" id="newstab1">
#         <a href="//news.nate.com/" onclick="newsBox.clickTabLink('tab1_set1');return false;" title="뉴스탭 열기">
#          뉴스
#         </a>
#        </h4>
#        <h4 class="menu02" id="newstab2">
#         <a href="//sports.news.nate.com/" onclick="newsBox.clickTabLink('tab2_spo');return false;" title="스포츠탭 열기">
#          스포츠
#         </a>
#        </h4>
#        <h4 class="menu03" id="newstab3">
#         <a href="//news.nate.com/ent/section?mid=e0100;" onclick="newsBox.clickTabLink('tab3_ent');return false;" title="연예탭 열기">
#          연예
#         </a>
#        </h4>
#        <h4 class="menu04" id="newstab4" style="display:none;">
#        </h4>
#        <h4 class="menu05" id="newstab5">
#         <a href="//news.nate.com/rank/?mid=n1000" onclick="newsBox.clickTabLink('tab5_ranking');return false;" title="랭킹뉴스탭 열기">
#          랭킹뉴스
#         </a>
#        </h4>
#       </div>
#       <div class="content type_news" id="newsContType" onfocusin="newsBox.rollingStop();" onfocusout="newsBox.rollingStart();">
#        <div class="tabCnt">
#         <div class="rankBox" id="div_rank_sisa">
#         </div>
#         <div class="rankBox" id="div_rank_spo">
#         </div>
#         <div class="rankBox" id="div_rank_ent">
#         </div>
#         <ul class="type_thumb type02" id="newsImg_ul_1">
#          <li id="newsImg0">
#           <a href="//ps.news.nate.com/photo/slideShow?cid=1027635&amp;mid=e0102" onclick="setTabInfo();ndrclick('MEF06', 'NH_03_01_02-20231208103333');" target="_self">
#            <em class="icon slide">
#             슬라이드
#            </em>
#            <span class="thumb_img">
#             <img alt="" src="//news.nateimg.co.kr/etc/cms/2023/12/08/1701999162_475.jpg" width="168"/>
#            </span>
#            <span class="txt">
#             '솔로' 18기, 블랙핑크 리사 닮은꼴 강림…데프콘도 과몰입
#            </span>
#           </a>
#          </li>
#          <li id="newsImg1">
#           <a href="//sports.news.nate.com/abrbaseball/photo?page=1&amp;cid=1027583&amp;fix=1027583" onclick="setTabInfo();ndrclick('MEF07', 'NH_02_01_01-20231208095007');" target="_self">
#            <em class="icon slide">
#             슬라이드
#            </em>
#            <span class="thumb_img">
#             <img alt="" src="//news.nateimg.co.kr/etc/cms/2023/12/08/1701986179_893.jpg" width="168"/>
#            </span>
#            <span class="txt">
#             "김하성이 상습폭행" 신분 밝히고 사진 공개한 임혜동
#            </span>
#           </a>
#          </li>
#          <li id="newsImg2">
#           <a href="//ps.news.nate.com/photo/slideShow?cid=1027640" onclick="setTabInfo();ndrclick('MEF08', 'NH_01_01_01-20231208105324');" target="_self">
#            <em class="icon slide">
#             슬라이드
#            </em>
#            <span class="thumb_img">
#             <img alt="" src="//news.nateimg.co.kr/etc/cms/2023/12/08/1702000379_259.png" width="168"/>
#            </span>
#            <span class="txt">
#             공직선거법 위반 공판 출석하는 이재명 대표
#            </span>
#           </a>
#          </li>
#         </ul>
#         <ul class="type_text" id="newsTxt_ul_1">
#          <li id="newsTxt_li_0">
#           <strong>
#            <a href="//news.nate.com/section?mid=n0400&amp;n=986863#cid986863" onclick="setTabInfo();ndrclick('MEB39', 'NH_01_02_02-20231208101447');" target="_self">
#             '돈봉투' 송영길 검찰 출석…"검찰은 하나회, 민주공화국 마비"
#            </a>
#           </strong>
#          </li>
#          <li id="newsTxt_li_1">
#           <a href="//news.nate.com/view/20231208n07698" onclick="setTabInfo();ndrclick('MEB41', 'NH_01_02_03-20231208100945');" target="_self">
#            홍익표 "20일에 반드시 예산안 통과…야당 단독안이라도 한다"
#           </a>
#          </li>
#          <li id="newsTxt_li_2">
#           <a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=11001&amp;n=966595#cid966595" onclick="setTabInfo();ndrclick('MEB43', 'NH_01_02_11-20231208103846');" target="_self">
#            "수억원 연봉에 칼퇴근까지 보장합니다" 홍보에도…지원율 꼴찌한 소아과 의사
#           </a>
#          </li>
#          <li id="newsTxt_li_3">
#           <a href="//sports.news.nate.com/basketvolley/#cid709821" onclick="setTabInfo();ndrclick('MEB45', 'NH_02_02_01-20231208095006');" target="_self">
#            '솔로지옥 나들이' LG 이관희 "농구할 때처럼 가식 없이 찍었다"
#           </a>
#          </li>
#          <li id="newsTxt_li_4">
#           <a href="//news.nate.com/ent/subsection?mid=e1100&amp;n=1027608#cid1027608" onclick="setTabInfo();ndrclick('MEC65', 'NH_03_02_01-20231208103246');" target="_self">
#            소유·송가인, 임영웅 열애·결혼설 해명…"우연한 만남"
#           </a>
#          </li>
#         </ul>
#         <ul class="type_text" id="newsTxt_ul_2">
#          <li id="newsTxt_li_5">
#           <a href="//news.nate.com/hissue/groupList?mid=n0412&amp;isq=9998&amp;sisq=9968" onclick="setTabInfo();ndrclick('MEF12', 'NH_01_02_09-20231208090312');" target="_self">
#            치솟는 물가에 대충싼 점심도시락…'호흡기 감염' 부른다
#           </a>
#          </li>
#          <li id="newsTxt_li_6">
#           <strong>
#            <a href="//news.nate.com/view/20231208n11209" onclick="setTabInfo();ndrclick('MEF14', 'NH_01_02_09-20231208110251');" target="_self">
#             민주 전략공관위원장에 '정세균계' 안규백…"승리가 유일 원칙"
#            </a>
#           </strong>
#          </li>
#          <li id="newsTxt_li_7">
#           <a href="//sports.news.nate.com/hissue/clstList?mid=s0106&amp;isq=8588&amp;n=967932#cid967932" onclick="setTabInfo();ndrclick('MEF16', 'NH_02_02_04-20231208075949');" target="_self">
#            "토론토, 오타니 영입 실패하면 다음 타킷은 이정후" ESPN 전망
#           </a>
#          </li>
#          <li id="newsTxt_li_8">
#           <a href="//news.nate.com/view/20231208n04494" onclick="setTabInfo();ndrclick('MEF18', 'NH_03_02_03-20231208081436');" target="_self">
#            다니엘, '2년 열애' 韓 여성과 오늘(8일) 결혼…사회 전현무
#           </a>
#          </li>
#          <li id="newsTxt_li_9">
#           <a href="//news.nate.com/view/20231208n04782" onclick="setTabInfo();ndrclick('MEF20', 'NH_03_02_01-20231208082016');" target="_self">
#            "모친 별세"…고원희, 부고 문자에 깜짝 "점점 교묘해져"
#           </a>
#          </li>
#         </ul>
#         <ul class="type_text" id="newsTxt_ul_3">
#          <li id="newsTxt_li_10">
#           <a href="//news.nate.com/hissue/clstList?mid=n0309&amp;isq=11002&amp;n=995762#cid995762" onclick="setTabInfo();ndrclick('MEB47', 'NH_01_03_01-20231208103413');" target="_self">
#            딸기케익 '9만원' 시대…개인 빵집은 "안 팔아요" 속사정
#           </a>
#          </li>
#          <li id="newsTxt_li_11">
#           <strong>
#            <a href="//news.nate.com/section?mid=n0300&amp;n=1027622#cid1027622" onclick="setTabInfo();ndrclick('MEB49', 'NH_01_02_04-20231208094131');" target="_self">
#             10월 경상수지 2년래 최대…수출, 반도체 회복에 14개월만에 '플러스'
#            </a>
#           </strong>
#          </li>
#          <li id="newsTxt_li_12">
#           <a href="//news.nate.com/view/20231208n09183" onclick="setTabInfo();ndrclick('MEB51', 'NH_01_03_01-20231208102204');" target="_self">
#            "가짜 한강뷰 아파트 126채를 팔다? 전청조 뺨친 서준혁"
#           </a>
#          </li>
#          <li id="newsTxt_li_13">
#           <a href="//news.nate.com/view/20231208n02845" onclick="setTabInfo();ndrclick('MEB53', 'NH_02_02_06-20231208064328');" target="_self">
#            '보류권 풀어달라' LG 부탁 거절하더니, MVP의 전격 복귀, 최강 외인 트리오 완성하다
#           </a>
#          </li>
#          <li class="half" id="newsTxt_li_14">
#           <a href="//news.nate.com/hissue/clstList?mid=e0100&amp;isq=7377&amp;n=1027600#cid1027600" onclick="setTabInfo();ndrclick('MEC67', 'NH_03_02_02-20231208083246');" target="_self">
#            차태현, 美서 공황장애 실신→응급실行
#           </a>
#           <i>
#            |
#           </i>
#           <span class="icon vod">
#            vod
#           </span>
#           <a href="//tv.nate.com/clip/4901821" onclick="setTabInfo();ndrclick('MEC68', 'NH_03_02_03-20231208083246');" target="_self">
#            박경림 보이스피싱
#           </a>
#          </li>
#         </ul>
#         <ul class="type_thumb type01 nHide" id="newsImg_ul_2">
#          <li id="newsImg3">
#          </li>
#          <li id="newsImg4">
#          </li>
#         </ul>
#         <div class="overlay_plus type01" id="newsPlusLayer" style="display:none">
#          <div class="plus_content">
#           <iframe frameborder="0" height="470" id="newsIfr" scrolling="no" src="about:blank" title="뉴스플러스 아이프레임" width="304">
#           </iframe>
#           <button class="close" onclick="closeNewsPlus();ndrclick('MEC49','');" title="뉴스플러스 레이어 닫기" type="button" value="뉴스플러스 레이어 닫기">
#            뉴스플러스 레이어 닫기
#           </button>
#          </div>
#         </div>
#        </div>
#        <div class="bizCnt">
#         <div class="isKeyword">
#          <h4>
#           실시간 이슈 키워드
#          </h4>
#          <ol class="isKeywordList" id="olLiveIssueKeyword">
#           <li>
#            <span class="num_rank">
#             6
#            </span>
#            <a class="ik" href="https://news.nate.com/search?q=임혜동" onclick="newsBox.clickSearchKeyword('임혜동');return false;" onmousedown="nc('MEH21')">
#             <span class="txt_rank">
#              임혜동
#             </span>
#             <span class="fc down">
#              <span class="nHide">
#               하락
#              </span>
#              2
#             </span>
#            </a>
#           </li>
#           <li>
#            <span class="num_rank">
#             7
#            </span>
#            <a class="ik" href="https://news.nate.com/search?q=차태현 美서 공황장애" onclick="newsBox.clickSearchKeyword('차태현 美서 공황장애');return false;" onmousedown="nc('MEH22')">
#             <span class="txt_rank">
#              차태현 美서 공황장애
#             </span>
#             <span class="fc up">
#              <span class="nHide">
#               상승
#              </span>
#              1
#             </span>
#            </a>
#           </li>
#           <li>
#            <span class="num_rank">
#             8
#            </span>
#            <a class="ik" href="https://news.nate.com/search?q=전장연 혜화역 무정차" onclick="newsBox.clickSearchKeyword('전장연 혜화역 무정차');return false;" onmousedown="nc('MEH23')">
#             <span class="txt_rank">
#              전장연 혜화역 무정차
#             </span>
#             <span class="fc new">
#              <span class="nHide">
#               new
#              </span>
#             </span>
#            </a>
#           </li>
#           <li>
#            <span class="num_rank">
#             9
#            </span>
#            <a class="ik" href="https://news.nate.com/search?q=양정원" onclick="newsBox.clickSearchKeyword('양정원');return false;" onmousedown="nc('MEH24')">
#             <span class="txt_rank">
#              양정원
#             </span>
#             <span class="fc same">
#              <span class="nHide">
#               동일
#              </span>
#             </span>
#            </a>
#           </li>
#           <li>
#            <span class="num_rank">
#             10
#            </span>
#            <a class="ik" href="https://news.nate.com/search?q=다니엘 결혼 사회" onclick="newsBox.clickSearchKeyword('다니엘 결혼 사회');return false;" onmousedown="nc('MEH25')">
#             <span class="txt_rank">
#              다니엘 결혼 사회
#             </span>
#             <span class="fc same">
#              <span class="nHide">
#               동일
#              </span>
#             </span>
#            </a>
#           </li>
#          </ol>
#          <form accept-charset="euc-kr" action="https://news.nate.com/search" id="frmKeyword" name="frmKeyword" onsubmit="return false">
#           <input id="bizq" name="q" type="hidden" value=""/>
#          </form>
#         </div>
#         <div class="adBox">
#         </div>
#         <div class="todayBox" id="divBox">
#          <h3>
#           <span class="nHide">
#            서비스 바로가기 링크
#           </span>
#          </h3>
#          <ul class="svcLink">
#           <li>
#            <a href="https://fortune.nate.com/contents/freeunse/freeunseframe.nate?freeUnseId=today03" onmousedown="nc('MEH12');">
#             오늘의 운세
#            </a>
#           </li>
#           <li>
#            <a href="https://tv.nate.com/popular/all" onmousedown="nc('MEH17');">
#             오늘의 인기영상
#            </a>
#           </li>
#           <li>
#            <a href="https://toonnbook.nate.com/main/PN83006001" onmousedown="nc('MEH18');">
#             오늘의 웹툰
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <dl class="content_recommend">
#         <dt id="dtNewsRecomm">
#          <em>
#           뉴스
#          </em>
#         </dt>
#         <dd id="newsRecommend">
#          <a href="//news.nate.com/recent?mid=n0100" onmousedown="nc('MEF37');setTabInfo();">
#           최신뉴스
#          </a>
#          <a href="//news.nate.com/section?mid=n0200" onmousedown="nc('MEF38');setTabInfo();">
#           정치
#          </a>
#          <a href="//news.nate.com/section?mid=n0300" onmousedown="nc('MEF39');setTabInfo();">
#           경제
#          </a>
#          <a href="//news.nate.com/section?mid=n0400" onmousedown="nc('MEF40');setTabInfo();">
#           사회
#          </a>
#          <a href="//news.nate.com/section?mid=n0600" onmousedown="nc('MEF41');setTabInfo();">
#           IT/과학
#          </a>
#         </dd>
#        </dl>
#       </div>
#       <div class="nav" id="newsOptBtn">
#        <span id="newsMoreArea">
#         <em>
#          2
#         </em>
#         / 6
#        </span>
#        <button class="pause" id="newsRollingBtn" onclick="newsBox.changeRolling();" title="자동전환기능 정지" type="button" value="자동전환기능 정지">
#         자동전환기능 정지
#        </button>
#        <button class="prev" onclick="ndrclick('MEC42');newsBox.showPreNext('P');" title="이전 뉴스 보기" type="button" value="이전 뉴스 보기">
#         이전 뉴스 보기
#        </button>
#        <button class="next" onclick="ndrclick('MEC43');newsBox.showPreNext('N');" title="다음 뉴스 보기" type="button" value="다음 뉴스 보기">
#         다음 뉴스 보기
#        </button>
#       </div>
#       <div id="newsNotice">
#       </div>
#       <div class="overlay_ticker" id="ticker_lyr" style="display:none">
#        <div class="ticker_content">
#         <iframe frameborder="0" height="318" id="ticker_ifm" scrolling="no" src="about:blank" title="티커 아이프레임" width="728">
#         </iframe>
#         <button class="close" onclick="nateonTickerClose();" title="티커 닫기" type="button" value="티커 닫기">
#          티커 닫기
#         </button>
#        </div>
#       </div>
#      </div>
#      <script type="text/javascript">
#       //<![CDATA[
# 					loadSpecialBiRolling();
# 				//]]>
#      </script>
#      <!-- tiles:insertAttribute name="NateQ" /-->
#      <div class="area_contents" id="divContentsUpper">
#       <h3>
#        컨텐츠
#       </h3>
#       <div class="menu">
#        <h4 class="menu01 on">
#         <a href="//pann.nate.com/talk/ranking" onclick="objPannArea.clickTab(0);return false;" onmousedown="nc('PAN60')" title="Top랭킹">
#          Top랭킹
#         </a>
#        </h4>
#        <h4 class="menu02">
#         <a href="//pann.nate.com/talk/c20025" onclick="objPannArea.clickTab(1);return false;" onmousedown="nc('PAN61')" title="결시친">
#          결시친
#         </a>
#        </h4>
#        <h4 class="menu03">
#         <a href="//pann.nate.com/talk/c20038" onclick="objPannArea.clickTab(2);return false;" onmousedown="nc('PAN62')" title="10대톡">
#          10대톡
#         </a>
#        </h4>
#        <h4 class="menu04">
#         <a href="//pann.nate.com/talk/c20028" onclick="objPannArea.clickTab(3);return false;" onmousedown="nc('PAN63')" title="연예톡">
#          연예톡
#         </a>
#        </h4>
#        <h4 class="menu05">
#         <a href="//pann.nate.com/talk/c20019" onclick="objPannArea.clickTab(4);return false;" onmousedown="nc('PAN64')" title="회사톡">
#          회사톡
#         </a>
#        </h4>
#       </div>
#       <div class="content" id="pannList">
#        <ol class="rank">
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            1
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (128)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371559268" onmousedown="nc('PAO80');objPannArea.clickContents(0);">
#            나한테 빌붙으려는 시조카 남친
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            2
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (277)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371559476" onmousedown="nc('PAO81');objPannArea.clickContents(0);">
#            추가)임신한 와이프 이게 맞나요?
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            3
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (115)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371560815" onmousedown="nc('PAO82');objPannArea.clickContents(0);">
#            현재 커뮤에서 논란인 찌디 영상
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            4
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (260)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371559864" onmousedown="nc('PAO83');objPannArea.clickContents(0);">
#            방탈죄송)성인이 매장들어가서 와이파이 비번 물어보면 궁상맞아보이나요?
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            5
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (85)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371559780" onmousedown="nc('PAO84');objPannArea.clickContents(0);">
#            우리친가 고모들 빼고 다 이혼함
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            6
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (86)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371562153" onmousedown="nc('PAO85');objPannArea.clickContents(0);">
#            한소희 코 진짜 실리콘 없이 신기하다
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            7
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (70)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371560231" onmousedown="nc('PAO86');objPannArea.clickContents(0);">
#            제가 진상인가요?
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            8
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (78)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371559524" onmousedown="nc('PAO87');objPannArea.clickContents(0);">
#            며느리 밥은 안주는 시가집
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            9
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (214)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371563214" onmousedown="nc('PAO88');objPannArea.clickContents(0);">
#            윈터 카리나 이젠 비비지도 못함
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            10
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (58)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371560233" onmousedown="nc('PAO89');objPannArea.clickContents(0);">
#            유치원 엄마들 출산 대화
#           </a>
#          </div>
#         </li>
#        </ol>
#        <ol class="rank" start="11">
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            11
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (178)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371563288" onmousedown="nc('PAO90');objPannArea.clickContents(0);">
#            정치 성향때문애 파혼 했어요
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            12
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (48)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371562578" onmousedown="nc('PAO91');objPannArea.clickContents(0);">
#            이거 손절 너무 빠른거아님?
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            13
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (42)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371559267" onmousedown="nc('PAO92');objPannArea.clickContents(0);">
#            "콘돔 NO, 배에 힘을 빡 줘"..'고딩엄빠3' 김나라
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            14
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (44)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371560259" onmousedown="nc('PAO93');objPannArea.clickContents(0);">
#            라이즈 인기멤은 ㄹㅇ 이유가 있늠
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            15
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (39)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371559530" onmousedown="nc('PAO94');objPannArea.clickContents(0);">
#            해찬 아이브이서랑 친해??
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            16
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (38)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371561987" onmousedown="nc('PAO95');objPannArea.clickContents(0);">
#            우리 아빠 성형외과 의사인데
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            17
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (41)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371559857" onmousedown="nc('PAO96');objPannArea.clickContents(0);">
#            태용 길빵 일본에서도 난리났네 ㄷㄷ
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            18
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (44)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371560513" onmousedown="nc('PAO97');objPannArea.clickContents(0);">
#            제니 위력 이거보고 한번더 느낌ㅋㅋㅋㅋㅋㅋㅋ
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            19
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (33)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371563540" onmousedown="nc('PAO98');objPannArea.clickContents(0);">
#            지디 이름으로 콘서트하는 찌디
#           </a>
#          </div>
#         </li>
#         <li>
#          <div class="list_box">
#           <span class="num_rank">
#            20
#           </span>
#           <span class="emph">
#            <span class="nHide">
#             댓글수
#            </span>
#            (48)
#           </span>
#           <a class="link" href="https://pann.nate.com/talk/371560848" onmousedown="nc('PAO99');objPannArea.clickContents(0);">
#            커플의 해외여행_ 어때 보이시나요 ??
#           </a>
#          </div>
#         </li>
#        </ol>
#       </div>
#       <!-- nav -->
#       <div class="nav">
#        <span>
#         <a href="//pann.nate.com/" onmousedown="nc('PAN65')">
#          판홈
#         </a>
#         <i>
#          |
#         </i>
#         <em>
#          1
#         </em>
#         / 5
#        </span>
#        <button class="prev" onclick="objPannArea.clickButton('P');" onmousedown="nc('PAN98')" title="이전 컨텐츠 보기" type="button" value="이전 컨텐츠 보기">
#         이전 컨텐츠 보기
#        </button>
#        <button class="next" onclick="objPannArea.clickButton('N');" onmousedown="nc('PAN99')" title="다음 컨텐츠 보기" type="button" value="다음 컨텐츠 보기">
#         다음 컨텐츠 보기
#        </button>
#       </div>
#       <!-- //nav -->
#      </div>
#      <div class="area_issue" id="divIssueUp">
#       <h3>
#        키워드
#       </h3>
#       <div class="menu">
#        <div class="keyword_list">
#         <div class="list_top">
#          <h4 class="menu08">
#           <a href="javascript:issueContents.clickIssueUpNateTv(0)" onmousedown="nc('CTG08')">
#            TV
#           </a>
#          </h4>
#          <h4 class="menu01">
#           <a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CTG01');">
#            여행/맛집
#           </a>
#          </h4>
#          <h4 class="menu02">
#           <a href="javascript:issueContents.clickIssueUpCategory(2, 0)" onmousedown="nc('CTG02');">
#            뷰티
#           </a>
#          </h4>
#          <h4 class="menu03">
#           <a href="javascript:issueContents.clickIssueUpCategory(3, 0)" onmousedown="nc('CTG03');">
#            푸드
#           </a>
#          </h4>
#          <h4 class="menu04">
#           <a href="javascript:issueContents.clickIssueUpToonNBook()" onmousedown="nc('CTG09');">
#            만화/웹툰
#           </a>
#          </h4>
#          <h4 class="menu05">
#           <a href="javascript:issueContents.clickIssueUpCategory(5, 0)" onmousedown="nc('CTG05');">
#            패션
#           </a>
#          </h4>
#          <h4 class="menu06">
#           <a href="javascript:issueContents.clickIssueUpCategory(6, 0)" onmousedown="nc('CTG06');">
#            라이프
#           </a>
#          </h4>
#          <h4 class="menu07 on" id="issueTabShopping">
#           <a href="javascript:issueContents.clickIssueUpShopping()" onmousedown="nc('CTG07');">
#            쇼핑
#           </a>
#          </h4>
#         </div>
#         <div class="list_btm" id="divIssueKeyword">
#          <h5 class="shopping">
#           최신 쇼핑소식과 트랜드를 확인하세요!
#          </h5>
#         </div>
#        </div>
#       </div>
#       <div class="content" id="divIssueUpContents">
#       </div>
#       <div class="content type_err nHide" id="emergencyLayer">
#        <h4 class="">
#         쇼핑탭 점검중
#        </h4>
#        <p>
#         불편을 드려 죄송합니다.
#         <br>
#          더 좋은 서비스를 위해
#          <br>
#           <strong>
#            쇼핑탭은 지금 점검
#           </strong>
#           중입니다.
#          </br>
#         </br>
#        </p>
#        <a href="https://shopping.nate.com/">
#         네이트 쇼핑으로 바로가기
#        </a>
#       </div>
#       <div class="overlay_ally" style="display:none;">
#       </div>
#       <div class="movplay" id="movieSec">
#        <div class="issuemov">
#         <div id="divPlayer">
#         </div>
#         <a class="btn_view_detail" href="" id="movieDetailLink" onmousedown="javascript:nc('MVA02');" target="" title="광고 자세히보기">
#          광고 자세히보기
#         </a>
#         <button class="btn_x_small_white" onclick="issueContents.closeMovie();" onmousedown="nc('CZA02')" title="동영상 플레이 레이어 닫기" type="button" value="동영상 플레이 레이어 닫기">
#          동영상 플레이 레이어 닫기
#         </button>
#        </div>
#        <span class="shadow">
#        </span>
#       </div>
#       <div class="content type_err tbe nHide" id="divToonNBookErrLayer">
#        <h4 class="">
#         만화/웹툰탭 점검중
#        </h4>
#        <p>
#         불편을 드려 죄송합니다.
#         <br/>
#         더 좋은 서비스를 위해
#         <br/>
#         <strong>
#          만화/웹툰탭은 지금 점검
#         </strong>
#         중입니다.
#        </p>
#        <a href="https://toonnbook.nate.com">
#         네이트 툰앤북으로 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="area_best">
#       <h3>
#        베스트 컨텐츠
#       </h3>
#       <h4>
#        당신이 놓친 오늘의
#        <br/>
#        추천 콘텐츠
#       </h4>
#       <ul>
#        <li>
#         <a href="https://view.nate.com/enter/view/96899/" onmousedown="nc('RCM01');" title="정우성이 최근 밥을 많이 사 준 후배?">
#          <span class="thumb">
#           <img alt="정우성이 최근 밥을 많이 사 준 후배?" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701661508152.jpg" width="94"/>
#          </span>
#          <span class="title">
#           정우성이 최근 밥을 많이 사 준 후배?
#          </span>
#          <cite>
#           스타
#          </cite>
#         </a>
#        </li>
#        <li>
#         <a href="https://view.nate.com/travel/view/90872/" onmousedown="nc('RCM02');" title="차갑게 먹어도 맛난 어묵볶음 레시피">
#          <span class="thumb">
#           <img alt="차갑게 먹어도 맛난 어묵볶음 레시피" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701660551700.jpg" width="94"/>
#          </span>
#          <span class="title">
#           차갑게 먹어도 맛난 어묵볶음 레시피
#          </span>
#          <cite>
#           푸드
#          </cite>
#         </a>
#        </li>
#        <li>
#         <a href="https://news.nate.com/view/20231203n02317" onmousedown="nc('RCM03');" title="단점을 찾을 수 없는 절정의 최근 미모">
#          <span class="thumb">
#           <img alt="단점을 찾을 수 없는 절정의 최근 미모" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701660002956.jpg" width="94"/>
#          </span>
#          <span class="title">
#           단점을 찾을 수 없는 절정의 최근 미모
#          </span>
#          <cite>
#           스타
#          </cite>
#         </a>
#        </li>
#        <li>
#         <a href="https://news.nate.com/view/20231130n12481" onmousedown="nc('RCM04');" title="청순 여신의 색다른 파자마 룩 화보">
#          <span class="thumb">
#           <img alt="청순 여신의 색다른 파자마 룩 화보" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2023/12/1701661585502.jpg" width="94"/>
#          </span>
#          <span class="title">
#           청순 여신의 색다른 파자마 룩 화보
#          </span>
#          <cite>
#           스타
#          </cite>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="area_ranking">
#       <h3>
#        랭킹
#       </h3>
#       <div class="menu">
#        <h4 class="menu01">
#         Biz 추천검색어
#        </h4>
#       </div>
#       <div class="content" onmouseout="nateRanking.startRolling()" onmouseover="nateRanking.stopRolling()">
#        <ul class="type_thumb">
#         <li>
#          <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=프랜차이즈창업" onmousedown="nc('RKM41')" title="프랜차이즈 창업컨설팅">
#           <span class="thumb">
#            <img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1700192965_2638.jpg"/>
#           </span>
#           <span class="text">
#            프랜차이즈 창업컨설팅
#           </span>
#           <span class="desc">
#            창업 순위와 시장 동향
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=사무실이사" onmousedown="nc('RKM42')" title="사무실이사 가격비교">
#           <span class="thumb">
#            <img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1700192967_4556.jpg"/>
#           </span>
#           <span class="text">
#            사무실이사 가격비교
#           </span>
#           <span class="desc">
#            사무실이사 비용 무료 견적
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=근조화환" onmousedown="nc('RKM43')" title="고품격 근조화환">
#           <span class="thumb">
#            <img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1700192966_75.jpg"/>
#           </span>
#           <span class="text">
#            고품격 근조화환
#           </span>
#           <span class="desc">
#            위로의 마음을 전하세요
#           </span>
#          </a>
#         </li>
#         <li class="commercial">
#          <a href="http://tong-dal.com/" onmousedown="nc('RKM44')" target="_blank" title="통신의달인">
#           <span class="thumb">
#            <img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1673421214_4029.jpg"/>
#           </span>
#           <span class="text">
#            통신의달인
#           </span>
#           <span class="desc">
#            인터넷가입은 딱 통신의달인
#           </span>
#          </a>
#         </li>
#         <li class="commercial">
#          <a href="https://www.etoos.com?_C_=92422549&amp;utm_source=pc&amp;utm_medium=nate&amp;utm_campaign=2023_nate&amp;utm_content=20231101_%EB%B9%84%EC%A6%88%EB%B0%94%EB%A1%9C%EA%B0%80%EA%B8%B0" onmousedown="nc('RKM45')" target="_blank" title="이투스 2만2천원 구독하기">
#           <span class="thumb">
#            <img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1700056572_8890.jpg"/>
#           </span>
#           <span class="text">
#            이투스 2만2천원 구독하기
#           </span>
#           <span class="desc">
#            모든인강 무제한 수강하기
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="paging_slide">
#        <span class="num_count_1">
#         <em>
#          2
#         </em>
#         / 2
#        </span>
#        <button class="btn prev" onclick="nateRanking.clickRankingBtn('P');" onmousedown="nc('RKN98');" title="이전" type="button">
#         이전
#        </button>
#        <button class="btn next" onclick="nateRanking.clickRankingBtn('N');" onmousedown="nc('RKN99');" title="다음" type="button">
#         다음
#        </button>
#       </div>
#      </div>
#      <hr/>
#      <h2>
#       쇼핑&amp; 광고 영역
#      </h2>
#      <div class="area_shopping" id="shopping" style="display:none">
#       <h3>
#        쇼핑
#       </h3>
#       <div class="mall1shop" id="shopitemMall">
#        <h3 class="tab" id="mall1Title">
#         <a class="link" href="http://shopping.nate.com" onmousedown="ndrclick2('NFA01')" target="_top">
#          쇼핑홈
#         </a>
#        </h3>
#        <div class="shopmall" id="mall1Box">
#        </div>
#        <h3 class="tab" id="mall2Title">
#         <a class="link" href="#" onmousedown="ndrclick2('NFC01')" target="_blank">
#         </a>
#        </h3>
#        <div class="shopmall nHide" id="mall2Box">
#        </div>
#        <h3 class="tab" id="mall3Title">
#         <a class="link" href="#" onmousedown="ndrclick2('NFE01')" target="_blank">
#         </a>
#        </h3>
#        <div class="shopmall nHide" id="mall3Box">
#        </div>
#        <h3 class="tab" id="mall4Title">
#         <a class="link" href="#" onmousedown="ndrclick2('NFG01')" target="_blank">
#         </a>
#        </h3>
#        <div class="shopmall nHide" id="mall4Box">
#        </div>
#        <div id="relShopping">
#         <strong class="nHide">
#          쇼핑 관련 리스트
#         </strong>
#         <div class="paging_slide">
#          <button class="btn prev" id="shoppingPrev" onmousedown="ndrclick2('NFZ01')" title="이전" type="button">
#           쇼핑 이전 내용
#          </button>
#          <button class="btn next" id="shoppingNext" onmousedown="ndrclick2('NFZ02')" title="다음" type="button">
#           쇼핑 다음 내용
#          </button>
#         </div>
#        </div>
#       </div>
#       <script type="text/javascript">
#        //<![CDATA[
#     var nDt = new Date();
#     var verShop = '' + (nDt.getMonth()+1) + nDt.getDate() + nDt.getHours() + nDt.getMinutes();
# //]]>
#       </script>
#      </div>
#      <div class="area_shopping type_err" id="shopping_err" style="display:none">
#       <h4 class="">
#        쇼핑박스 점검중
#       </h4>
#       <p>
#        불편을 드려 죄송합니다.
#        <br>
#         더 좋은 서비스를 위해
#         <br/>
#         <strong>
#          쇼핑박스는 지금 점검
#         </strong>
#         중입니다.
#        </br>
#       </p>
#       <a href="http://shopping.nate.com">
#        네이트 쇼핑으로 바로가기
#       </a>
#      </div>
#      <div class="area_shopping_today">
#       <!-- tiles:insertAttribute name="shopRecommendation" /-->
#      </div>
#      <div class="area_quick" id="divQuickMenu">
#       <h3>
#        퀵링크
#       </h3>
#       <div class="area_sktad01">
#       </div>
#       <ul>
#        <li class="totop">
#         <a href="javascript:;" onmousedown="nc('RAB15');">
#          <span>
#           맨위로
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://tv.nate.com/" onmousedown="nc('RAB25');" title="네이트TV 서비스 가기">
#          네이트TV
#         </a>
#        </li>
#        <li>
#         <a href="https://toonnbook.nate.com/" onmousedown="nc('RAB24');" title="툰앤북 서비스 가기">
#          툰앤북
#         </a>
#        </li>
#        <li>
#         <a href="https://mobile.nate.com/decorate/mvno/top" onmousedown="nc('RAB19');" title="컬러링 서비스 가기">
#          컬러링
#         </a>
#        </li>
#        <li>
#         <a href="http://editor.nate.com/" onmousedown="nc('RAB23');" title="이슈UP추천 서비스 가기">
#          이슈UP추천
#         </a>
#        </li>
#        <li class="issue">
#         <a href="javascript:;" onmousedown="nc('RAB08');">
#          이슈
#          <em class="issueup">
#           UP
#          </em>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <hr/>
#     <div id="footer">
#      <h2>
#       푸터 영역
#      </h2>
#      <div class="notice">
#       <h3>
#        <a href="https://helpdesk.nate.com/web/notice/main" onmousedown="nc('NFT01');">
#         공지사항
#        </a>
#       </h3>
#       <a href="https://helpdesk.nate.com/web/notice/main-detail?id=8806" onmousedown="nc('NFT02');">
#        네이트 유료서비스 이용약관 개정 안내
#       </a>
#      </div>
#      <dl>
#       <dt>
#        네이트 공용 푸터
#       </dt>
#       <dd>
#        <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT21');">
#         회사소개
#        </a>
#        <span>
#         |
#        </span>
#        <a href="http://business.nate.com/" onmousedown="nc('NFT29');">
#         광고문의
#        </a>
#        <span>
#         |
#        </span>
#        <a href="/policy/legal.html" onmousedown="nc('NFT24');">
#         서비스 약관
#        </a>
#        <span>
#         |
#        </span>
#        <a href="/policy/privacy.html" onmousedown="nc('NFT25');">
#         <strong>
#          개인정보처리방침
#         </strong>
#        </a>
#        <span>
#         |
#        </span>
#        <a href="/policy/youthpolicy.html" onmousedown="nc('NFT26');">
#         청소년보호정책
#        </a>
#        <span>
#         |
#        </span>
#        <a href="http://helpdesk.nate.com/" onmousedown="nc('NFT11');">
#         고객센터
#        </a>
#        <span>
#         |
#        </span>
#        <span class="copyright">
#         ©
#         <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT41');" target="_blank">
#          <strong>
#           <span class="sk">
#            SK
#           </span>
#           Communications.
#          </strong>
#         </a>
#        </span>
#       </dd>
#      </dl>
#      <a class="view_all" href="/sitemap/index.html" onmousedown="nc('NFT12');">
#       서비스 전체보기
#      </a>
#     </div>
#     <hr/>
#     <div id="adContainer">
#      <h2>
#       광고 영역
#      </h2>
#      <div class="area_ad01" id="ad_layer1">
#      </div>
#      <div class="area_ad02" id="ad_layer2">
#      </div>
#      <div class="area_adual">
#       <div class="area_ad03">
#       </div>
#       <div class="area_ad04">
#       </div>
#      </div>
#      <div class="area_ad05 nHide" id="leftAd05Cj">
#       <a href="http://talkon.nate.com/service.html" onmousedown="nc('NBI11');" target="_blank">
#        <img alt="게임할땐 토크온!" height="110" src="//main.nateimg.co.kr/img/v6/talkon_55x110.gif" width="55"/>
#       </a>
#      </div>
#      <div class="area_ad06">
#      </div>
#      <div class="area_sktad02">
#      </div>
#      <div class="area_ad09">
#       <!-- iframe id="ifrm_ad09" name="ifrm_ad09" frameborder="0" width="728" height="90" scrolling="no" src="about:blank" title="광고"></iframe -->
#      </div>
#      <div class="area_ad10">
#       <a href="https://www.cymera.com/main/ko" onmousedown="setNcCode('NAA21|NAA22',iSvcSeqC-1);">
#        <img alt=" 싸이메라" height="90" src="//main.nateimg.co.kr/img/cms/content_pool/2023/11/1699344089055.png" width="332"/>
#       </a>
#      </div>
#      <div id="ad_layer3">
#      </div>
#      <div id="ad_layer4" style="display:none;">
#      </div>
#     </div>
#    </div>
#    <div id="cbContainer">
#     <div class="area_ad08" id="cbLayer" style="display: none">
#      <span class="commTxt">
#       한눈에 보는 오늘
#       <em>
#        NATE
#       </em>
#       와 함께 하루를 시작하세요.
#      </span>
#      <a href="javascript:;" id="cbLayerLink" title="NATE를 시작페이지로">
#       NATE를 시작페이지로
#      </a>
#     </div>
#    </div>
#   </div>
#   <div class="setting_moblie" id="plus_footer" style="display: none">
#   </div>
#   <span id="layerTemp">
#   </span>
#   <script src="/js/common/natead_081.js?v=20200206_02" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    if (isiPad) {
# 		document.write('<img src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/ipad/]" width="0"  height="0" border="0" alt="" />');
# 	}
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
# try{
#
# 	var contentsUpperTabMenu = ["null", "http://pann.news.nate.com/info", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_gray.gif", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_black.gif" ];
# 	var contentsUpperTopLink = [["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"]];
# 	var contentsUpperSecondPannTitle = ["톡커들의 선택"];
#
# }catch (e) { }
# //]]>
#   </script>
#   <!--natemain-->
#   <script type="text/javascript">
#    //<![CDATA[
#  CFN_type = ''; CFN_id = ''; CFN_cn = ''; CFN_cmn = ''; CFN_link = ''; CFN_link_id = ''; id = (CFN_type == 'N') ? CFN_id : CFN_link_id; cyid = (CFN_type == 'C') ? CFN_id : CFN_link_id; name = CFN_cn; isEmpas = ('' == '1'); refererDomain = ''; CFN_cust_tp_cd = ''; CFN_sex_cd = ''; loginType = ''; isMobile = 'F'; CFN_link_cust_tp_cd = ''; CFN_link_stat_cd = ''; var ndrLoginStatus = (isNateLogin) ? 'login' : ((bLogout) ? 'byebye' : 'logout'); try { divReferer(refererDomain); } catch (e) { } try { if (isNateLogin) fillPersonInfo();} catch (e) { } pageEnd('', '/');//]]>
#   </script>
#  </body>
# </html>

# %% [markdown]
# #### BeautifulSoup 패키지의 파싱 함수
# - find(태그,[{속성명:속성값}])
#     - 지정한 태그 중 첫번째 만나는 태그만 추출 또는 지정한 태그 중 해당 속성과 속상값을 갖고있는 태그의 첫번째 태그
# - findAll(태그,[{속성명:속성값}])
#     - 지정한 태그 모두 찾아서 추출
#     - 첫번째 이외의 태그를 추출할 때 사용
#     - list 형태로 반환
# - find_all(태그,[{속성명:속성값}])
#     - findAll 함수와 동일

# %%
# test html
html_str = "<html><div>hello</div></html>"

# html코드를 파싱 객체로 변환

#<class 'bs4.BeautifulSoup'> bs4 객체 - 관련함수 사용 가능

# html 태그로 추출
# Out:
# <class 'bs4.BeautifulSoup'>
# <html><div>hello</div></html>

# %%
# <div>hello</div> : 여는 div 태그부터 닫는 div 태그까지

# html코드에서 첫번째 만나는 div태그의 내부 문자열 반환
# Out:
# 'hello'

# %%
html_str = """
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
    </body>
</html>
"""

# %%
html_str = """
<html>
    <body>
        <ul class="greet">
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
        <ul class="reply">
            <li>ok</li>
            <li>no</li>
            <li>sure</li>
        </ul>
    </body>
</html>
"""

# %%
# 태그중에 특정 속성을 갖고 있는 태그를 추출
# ul 태그중 class 속성값이 greet인 태그를 추출

# %%
# ul 태그중 class 속성값이 reply인 태그를 추출

# ul 태그중에 class 속성값이 reply인 첫번째 ul태그 반환

# ul 태그중에 class 속성값이 reply인 모든 ul태그 반환
# 해당 ul태그가 여러개면 모두 반환

# %%
# bs_obj 객체의 모든 li태그 추출

# %%
#  class속성값이 greet 인 ul 태그 내의 모든 li 태그 추출

# %%
html_str = """
<html>
    <body>
        <h1 id='title'>Hello Python</h1>
        <p id="crawling">웹 크롤링</p>
        <p id="parsing">파싱</p>
    </body>
</html>"""

# %%
d

# %%
# h1 태그 중 id가 title인 태그 추출
d
# Out:
# <h1 id="title">Hello Python</h1>

# %%
# p태그 중 id가 qarsing 인 태그
# Out:
# <p id="parsing">파싱</p>

# %% [markdown]
# #### bs4 형제 노드 찾기

# %%
html_str = """
<html>
    <body>
        <h1>파이썬 프로그래밍</h1>
        <p>웹 페이지 분석</p><p>크롤링</p><p>파싱</p>        
    </body>
</html>
"""

# %%
# html문서에서 첫번째 나타나는 p 태그
# Out:
# <p>웹 페이지 분석</p>

# %%
# html문서에서 나타나는 모든 p 태그
# Out:
# [<p>웹 페이지 분석</p>, <p>크롤링</p>, <p>파싱</p>]

# %%
# 첫번째 p태그를 기준으로 다음 p태그를 반환
# Out:
# <p>크롤링</p>

# %%
# 첫번째 p태그를 기준으로 다음 다음 p태그를 반환
# Out:
# <p>파싱</p>

# %% [markdown]
# ####  속성값 추출하기
# #### a 태그의 href 속성

# %%
html_str = """
<html>
    <body>
        <ul class="ko">
            <li><a href="https://www.naver.com/">네이버</a></li>
            <li><a href="https://www.daum.net/">다음</a></li>
        </ul>
        <ul class="sns">
            <li><a href="https://www.goole.com/">구글</a></li>
            <li><a href="https://www.facebook.net/">페이스북</a></li>
        </ul>
    </body>
</html>
"""

# %%
# Out:
# [<a href="https://www.naver.com/">네이버</a>,
#  <a href="https://www.daum.net/">다음</a>,
#  <a href="https://www.goole.com/">구글</a>,
#  <a href="https://www.facebook.net/">페이스북</a>]

# %%
# 태그의 속성값을 추출
# 태그객체['속성명']
# Out:
# 'https://www.naver.com/'

# %%
# Out:
# '네이버'

# %%
hrefs=[]
# Out:
# https://www.naver.com/
# https://www.daum.net/
# https://www.goole.com/
# https://www.facebook.net/

# %%
hrefs=[]
name = []

# %%
hrefs
name

import pandas as pd

# %%
import bs4
html_str = """
<html>
   <body>
    	<div id="wrap">
        	<div id="mainMenuBox">                	
                <ul>  
                    <li><a href="#">패션잡화</a></li>    
                    <li><a href="#">주방용품</a></li>                     	          
                    <li><a href="#">생활건강</a></li>
                    <li><a href="#">DIY가구</a></li>
                </ul>
            </div>
        	<div>
            	<table>
                	<tr><td><img src="shoes1.jpg"></td>
                    	  <td><img src="shoes2.jpg"></td>
                    	  <td><img src="shoes3.jpg"></td></tr>
                    <tr id="prdName"><td>솔로이스트<br>걸리쉬 리본단화</td>
                    	  <td>맥컬린<br>그레이가보시스트랩 펌프스</td>
                          <td>맥컬린<br>섹슈얼인사이드펌프스</td></tr>
                    <tr id="price"><td>100,000원</td><td>200,000원</td><td>120,000원</td></tr>
                </table>
            </div>
            <div id="out_box">
            	<div class="box">
                	<h4>공지사항</h4>
                    <hr>
                    <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br>
                    <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br>
                    <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>                               
                </div>
                <div class="box">
                	<h4>커뮤니티</h4>
                    <hr>
                    <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br>
                    <a href="#">[가구] : 헌집 새집 베스트 가구</a><br>
                    <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br>
                 </div>
            </div>            
        </div>
    </body>
</html>"""

# %%
# bs 객체 생성

# %%
# 모든 a 태그
# Out:
# [<a href="#">패션잡화</a>,
#  <a href="#">주방용품</a>,
#  <a href="#">생활건강</a>,
#  <a href="#">DIY가구</a>,
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a>,
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a>,
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>,
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a>,
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a>,
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a>]

# %%
# selector : select(태그) 함수에 인수로 전달
# 해당 태그를 모두 찾아서 list로 반환
# Out:
# [<a href="#">패션잡화</a>,
#  <a href="#">주방용품</a>,
#  <a href="#">생활건강</a>,
#  <a href="#">DIY가구</a>,
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a>,
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a>,
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>,
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a>,
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a>,
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a>]

# %%
'''
            <div id="mainMenuBox">               
                <ul>  
                    <li><a href="#">패션잡화</a></li>    
                    <li><a href="#">주방용품</a></li>                             
                    <li><a href="#">생활건강</a></li>
                    <li><a href="#">DIY가구</a></li>
                </ul>
            </div>
'''

# %%
# Out:
# [<div id="wrap">
#  <div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>
#  <div>
#  <table>
#  <tr><td><img src="shoes1.jpg"/></td>
#  <td><img src="shoes2.jpg"/></td>
#  <td><img src="shoes3.jpg"/></td></tr>
#  <tr id="prdName"><td>솔로이스트<br/>걸리쉬 리본단화</td>
#  <td>맥컬린<br/>그레이가보시스트랩 펌프스</td>
#  <td>맥컬린<br/>섹슈얼인사이드펌프스</td></tr>
#  <tr id="price"><td>100,000원</td><td>200,000원</td><td>120,000원</td></tr>
#  </table>
#  </div>
#  <div id="out_box">
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>
#  </div>
#  </div>,
#  <div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>,
#  <div>
#  <table>
#  <tr><td><img src="shoes1.jpg"/></td>
#  <td><img src="shoes2.jpg"/></td>
#  <td><img src="shoes3.jpg"/></td></tr>
#  <tr id="prdName"><td>솔로이스트<br/>걸리쉬 리본단화</td>
#  <td>맥컬린<br/>그레이가보시스트랩 펌프스</td>
#  <td>맥컬린<br/>섹슈얼인사이드펌프스</td></tr>
#  <tr id="price"><td>100,000원</td><td>200,000원</td><td>120,000원</td></tr>
#  </table>
#  </div>,
#  <div id="out_box">
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>
#  </div>,
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>,
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>]

# %%
# id 선택자 : #을 활용

# id는 유일
# Out:
# [<div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>]

# %%
# Out:
# [<ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>]

# %%
# 자손 li를 찾음 : ul 태그 내부의 li가 반환

# 소스코드상 나타나는 li는 자손태그임, 자식태그인 li는 없음
# Out:
# [<li><a href="#">패션잡화</a></li>, <li><a href="#">주방용품</a></li>, <li><a href="#">생활건강</a></li>, <li><a href="#">DIY가구</a></li>]
# []

# %%
# id가 wrap인 태그의 모든 자식 div 태그
# Out:
# 3

# %%
# id가 wrap인 태그의 모든 자손 div 태그
# Out:
# 5

# %%
# 클래스 선택자(.클래스명)를 이용
# 클래스 속성값은 중복될 수 있음
# Out:
# [<div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>,
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>]

# %%
# 클래스 속성값이 box인 태그 중 두번째 태그안의 모든 a태그

# 클래스 속성값이 box인 태그 중 두번째 태그안의 모든 a태그중 첫번째 태그
# Out:
# <a href="#">[레시피] : 살 안찌는 야식 만들기</a>

# %%
# Out:
# '[배송] : 무표배송 변경 안내 18.10.20'

# %% [markdown]
# #### 웹 크롤링 시 주의 사항
#     - 웹 사이트는 언제든지 변경 될 수 있기 때문에 지금 실행하는 코드가 실행되지 않을 수 있다
